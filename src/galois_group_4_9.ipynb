# %% [markdown]
# ### Classifying Galois group of Quartic and Nonic extensions

# %%
from utils import *

current_dir = globals()['_dh'][0]

# %% [markdown]
# ### Quartic
#
# - `4T1`: $C_4$
# - `4T2`: $C_2^2$

# %%
df_quartic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_4_galois.csv")

# %%
df_stats(df_quartic_galois, "galois_label")
# Out:
# Number of rows: 182860
# Number of columns: 10007
# Head: shape: (5, 10_007)
# ┌───────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label     ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---       ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str       ┆ i64  ┆ str          ┆ i64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 4.0.125.1 ┆ 1    ┆ 4T1          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 1       │
# │ 4.0.144.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 16      ┆ 0       ┆ 0       ┆ 3       │
# │ 4.0.225.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 4.0.256.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 4.0.400.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 5       │
# └───────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬────────┬──────────┐
# │ galois_label ┆ len    ┆ percent  │
# │ ---          ┆ ---    ┆ ---      │
# │ str          ┆ u32    ┆ f64      │
# ╞══════════════╪════════╪══════════╡
# │ 4T1          ┆ 21873  ┆ 0.119616 │
# │ 4T2          ┆ 160987 ┆ 0.880384 │
# └──────────────┴────────┴──────────┘

# %%
run_experiments(df_quartic_galois, "quartic_galois", ["4T1", "4T2"], current_dir, [2])
# Out:
# Running experiment: quartic_galois_dt_zc_1000
# Data: quartic_galois_dt_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9999, balanced_acc=0.9995
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 0.9999 ± 0.0002
#
# per-class precision/recall/f1:
# 4T1: precision 1.0000 ± 0.0000, recall 0.9998 ± 0.0004, f1 0.9999 ± 0.0002
# 4T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[4.3738e+03 8.0000e-01]
#  [0.0000e+00 3.2197e+04]]
# Confusion matrix std (over folds):
# [[62.8726  1.6   ]
#  [ 0.     63.0479]]
# Running experiment: quartic_galois_dt_zc_1000_sq
# Data: quartic_galois_dt_zc_1000_sq, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9998, balanced_acc=0.9995
# Fold 2/5: acc=0.9999, balanced_acc=1.0000
# Fold 3/5: acc=0.9999, balanced_acc=0.9996
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=0.9998, balanced_acc=0.9996
# Averaged classification report (mean ± std):
# accuracy: 0.9999 ± 0.0001
# balanced_acc: 0.9997 ± 0.0002
#
# per-class precision/recall/f1:
# 4T1: precision 0.9997 ± 0.0003, recall 0.9995 ± 0.0004, f1 0.9996 ± 0.0003
# 4T2: precision 0.9999 ± 0.0001, recall 1.0000 ± 0.0000, f1 0.9999 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[4.3726e+03 2.0000e+00]
#  [1.4000e+00 3.2196e+04]]
# Confusion matrix std (over folds):
# [[64.0581  1.6733]
#  [ 1.2    63.3182]]
# Running experiment: quartic_galois_dt_zc_1000_prime
# Data: quartic_galois_dt_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9109, balanced_acc=0.7933
# Fold 2/5: acc=0.9125, balanced_acc=0.7944
# Fold 3/5: acc=0.9104, balanced_acc=0.7903
# Fold 4/5: acc=0.9118, balanced_acc=0.7969
# Fold 5/5: acc=0.9100, balanced_acc=0.7885
# Averaged classification report (mean ± std):
# accuracy: 0.9111 ± 0.0009
# balanced_acc: 0.7927 ± 0.0030
#
# per-class precision/recall/f1:
# 4T1: precision 0.6264 ± 0.0094, recall 0.6369 ± 0.0054, f1 0.6316 ± 0.0069
# 4T2: precision 0.9506 ± 0.0006, recall 0.9484 ± 0.0011, f1 0.9495 ± 0.0005
# Averaged confusion matrix (mean over folds):
# [[ 2786.6  1588. ]
#  [ 1662.  30535.4]]
# Confusion matrix std (over folds):
# [[58.315  19.97  ]
#  [36.5677 38.6036]]
# Running experiment: quartic_galois_dt_zc_1000_prime_power
# Data: quartic_galois_dt_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9999, balanced_acc=0.9995
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 0.9999 ± 0.0002
#
# per-class precision/recall/f1:
# 4T1: precision 1.0000 ± 0.0000, recall 0.9998 ± 0.0004, f1 0.9999 ± 0.0002
# 4T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[4.3738e+03 8.0000e-01]
#  [0.0000e+00 3.2197e+04]]
# Confusion matrix std (over folds):
# [[62.8726  1.6   ]
#  [ 0.     63.0479]]
# Running experiment: quartic_galois_dt_poly
# Data: quartic_galois_dt_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9484, balanced_acc=0.8731
# Fold 2/5: acc=0.9528, balanced_acc=0.8822
# Fold 3/5: acc=0.9538, balanced_acc=0.8766
# Fold 4/5: acc=0.9518, balanced_acc=0.8811
# Fold 5/5: acc=0.9511, balanced_acc=0.8780
# Averaged classification report (mean ± std):
# accuracy: 0.9516 ± 0.0018
# balanced_acc: 0.8782 ± 0.0032
#
# per-class precision/recall/f1:
# 4T1: precision 0.8073 ± 0.0093, recall 0.7818 ± 0.0061, f1 0.7943 ± 0.0065
# 4T2: precision 0.9705 ± 0.0006, recall 0.9746 ± 0.0016, f1 0.9725 ± 0.0011
# Averaged confusion matrix (mean over folds):
# [[ 3420.4   954.2]
#  [  817.2 31380.2]]
# Confusion matrix std (over folds):
# [[ 69.5028  20.5076]
#  [ 51.7355 102.4527]]
# Running experiment: quartic_galois_lr_zc_1000
# Data: quartic_galois_lr_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9964, balanced_acc=0.9895
# Fold 2/5: acc=0.9959, balanced_acc=0.9872
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9963, balanced_acc=0.9896
# Fold 4/5: acc=0.9958, balanced_acc=0.9893
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9958, balanced_acc=0.9884
# Averaged classification report (mean ± std):
# accuracy: 0.9960 ± 0.0003
# balanced_acc: 0.9888 ± 0.0009
#
# per-class precision/recall/f1:
# 4T1: precision 0.9876 ± 0.0019, recall 0.9793 ± 0.0019, f1 0.9834 ± 0.0009
# 4T2: precision 0.9972 ± 0.0003, recall 0.9983 ± 0.0003, f1 0.9978 ± 0.0001
# Averaged confusion matrix (mean over folds):
# [[ 4283.8    90.8]
#  [   53.8 32143.6]]
# Confusion matrix std (over folds):
# [[59.5966  8.8408]
#  [ 8.565  64.911 ]]
# Mean: 0.18934697177850668
# Median: 0.04272632246458127
# Std: 0.6009203372301775
# Top 30: [6.81976392 5.83791877 4.47119693 3.158068   2.92968564 2.27703781
#  1.96443445 1.86444132 1.71120886 1.69121775 1.62335782 1.56060569
#  1.17030818 1.1143298  1.02982554 1.02295968 1.02276017 0.90172163
#  0.89276059 0.88358051 0.87926149 0.78857672 0.7441996  0.67728532
#  0.62209234 0.61202938 0.5991462  0.59470527 0.56462822 0.56024571]
# Top 30 indices: [ 24 124  35  48  99 960 840 528  49   8 728 360 288 319  71 134 168 296
#  971  63  62  74  98  67 483  39 101 188 799 195]
# Bottom 30: [-6.10805048 -5.39949658 -5.03118811 -4.61201652 -4.11050947 -3.97924613
#  -3.51881451 -3.39970316 -2.96366401 -2.78696736 -2.59075151 -2.2100846
#  -2.01412546 -1.9602877  -1.94637471 -1.75869825 -1.61573062 -1.35730401
#  -1.22022598 -1.03954281 -0.94819547 -0.93293442 -0.90961852 -0.90178203
#  -0.87925839 -0.78423096 -0.74702885 -0.7417892  -0.70291112 -0.68363836]
# Bottom 30 indices: [  4   0  30 624  28  22  80  18  16  19 323   1  12   3 342  15  14 199
#   37 399  10   7  41  29  65 242  33  32 639  79]
# Mean: 1.6648616839888273
# Median: 1.3654569315864342
# Std: 1.5838160829773744
# Running experiment: quartic_galois_lr_zc_1000_normalized
# Data: quartic_galois_lr_zc_1000_normalized, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9947, balanced_acc=0.9840
# Fold 2/5: acc=0.9941, balanced_acc=0.9821
# Fold 3/5: acc=0.9942, balanced_acc=0.9826
# Fold 4/5: acc=0.9939, balanced_acc=0.9832
# Fold 5/5: acc=0.9937, balanced_acc=0.9815
# Averaged classification report (mean ± std):
# accuracy: 0.9941 ± 0.0003
# balanced_acc: 0.9827 ± 0.0009
#
# per-class precision/recall/f1:
# 4T1: precision 0.9826 ± 0.0020, recall 0.9677 ± 0.0016, f1 0.9751 ± 0.0014
# 4T2: precision 0.9956 ± 0.0002, recall 0.9977 ± 0.0003, f1 0.9966 ± 0.0002
# Averaged confusion matrix (mean over folds):
# [[ 4233.4   141.2]
#  [   74.8 32122.6]]
# Confusion matrix std (over folds):
# [[62.9145  7.0824]
#  [ 8.9532 64.4006]]
# Mean: 0.37452345879886695
# Median: 0.10540335473994429
# Std: 0.8879146687670253
# Top 30: [8.37904206 7.20388341 6.12836183 5.5407352  5.2770368  5.08415653
#  4.3261599  3.19612334 2.96954538 2.96230756 2.2356864  2.0724434
#  1.84083929 1.82844914 1.79258204 1.7426049  1.73602467 1.68580157
#  1.65833104 1.61238919 1.57825575 1.56520585 1.53532859 1.49028974
#  1.43934216 1.3714755  1.37091035 1.3667079  1.3583806  1.29803242]
# Top 30 indices: [ 24  48 960 840 528   8 360  35  99 288 168  97   3   6 483 440 174 134
#  195  13 485 224 123 120 863 269 296 511  98  62]
# Bottom 30: [-10.56517477  -7.58401302  -6.75893891  -6.28495681  -5.73824094
#   -5.50292025  -4.68522525  -3.66808632  -3.64091452  -3.35064539
#   -3.07122531  -3.02004864  -2.91580062  -2.79058448  -2.77187532
#   -2.51620181  -2.35975892  -2.2281833   -2.16664072  -2.09819302
#   -1.96655873  -1.95455891  -1.87682212  -1.84819169  -1.84084844
#   -1.78435492  -1.76610497  -1.7021545   -1.69144866  -1.61880365]
# Bottom 30 indices: [342 624  30  80  28  22  18 323  15  16 685 566 161 783 404 890 399  12
#  647 207 463 124 367  10 175 495 271  79 111 143]
# Mean: 3.177653587730015
# Median: 2.5751716989333993
# Std: 2.262207026216429
# Running experiment: quartic_galois_lr_zc_1000_sq
# Data: quartic_galois_lr_zc_1000_sq, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9799, balanced_acc=0.9207
# Fold 2/5: acc=0.9813, balanced_acc=0.9270
# Fold 3/5: acc=0.9813, balanced_acc=0.9244
# Fold 4/5: acc=0.9800, balanced_acc=0.9215
# Fold 5/5: acc=0.9801, balanced_acc=0.9209
# Averaged classification report (mean ± std):
# accuracy: 0.9805 ± 0.0006
# balanced_acc: 0.9229 ± 0.0025
#
# per-class precision/recall/f1:
# 4T1: precision 0.9885 ± 0.0008, recall 0.8472 ± 0.0050, f1 0.9124 ± 0.0027
# 4T2: precision 0.9796 ± 0.0008, recall 0.9987 ± 0.0001, f1 0.9891 ± 0.0004
# Averaged confusion matrix (mean over folds):
# [[ 3706.    668.6]
#  [   43.2 32154.2]]
# Confusion matrix std (over folds):
# [[54.827  25.0886]
#  [ 2.7129 62.0625]]
# Running experiment: quartic_galois_lr_zc_1000_prime
# Data: quartic_galois_lr_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8800, balanced_acc=0.5000
# Fold 2/5: acc=0.8793, balanced_acc=0.5000
# Fold 3/5: acc=0.8835, balanced_acc=0.5000
# Fold 4/5: acc=0.8785, balanced_acc=0.5000
# Fold 5/5: acc=0.8807, balanced_acc=0.5000
# Averaged classification report (mean ± std):
# accuracy: 0.8804 ± 0.0017
# balanced_acc: 0.5000 ± 0.0000
#
# per-class precision/recall/f1:
# 4T1: precision 0.0000 ± 0.0000, recall 0.0000 ± 0.0000, f1 0.0000 ± 0.0000
# 4T2: precision 0.8804 ± 0.0017, recall 1.0000 ± 0.0000, f1 0.9364 ± 0.0010
# Averaged confusion matrix (mean over folds):
# [[0.0000e+00 4.3746e+03]
#  [2.0000e-01 3.2197e+04]]
# Confusion matrix std (over folds):
# [[ 0.     63.0479]
#  [ 0.4    62.6846]]
# Running experiment: quartic_galois_lr_zc_1000_prime_power
# Data: quartic_galois_lr_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9968, balanced_acc=0.9890
# Fold 2/5: acc=0.9966, balanced_acc=0.9890
# Fold 3/5: acc=0.9966, balanced_acc=0.9892
# Fold 4/5: acc=0.9961, balanced_acc=0.9894
# Fold 5/5: acc=0.9966, balanced_acc=0.9891
# Averaged classification report (mean ± std):
# accuracy: 0.9965 ± 0.0002
# balanced_acc: 0.9892 ± 0.0001
#
# per-class precision/recall/f1:
# 4T1: precision 0.9916 ± 0.0022, recall 0.9794 ± 0.0006, f1 0.9855 ± 0.0008
# 4T2: precision 0.9972 ± 0.0001, recall 0.9989 ± 0.0003, f1 0.9980 ± 0.0001
# Averaged confusion matrix (mean over folds):
# [[ 4284.6    90. ]
#  [   36.2 32161.2]]
# Confusion matrix std (over folds):
# [[62.118   2.6833]
#  [ 9.7036 66.4482]]
# Running experiment: quartic_galois_lr_poly
# Data: quartic_galois_lr_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.2247, balanced_acc=0.4359
# Fold 2/5: acc=0.2198, balanced_acc=0.4448
# Fold 3/5: acc=0.2334, balanced_acc=0.4451
# Fold 4/5: acc=0.2273, balanced_acc=0.4424
# Fold 5/5: acc=0.2172, balanced_acc=0.4488
# Averaged classification report (mean ± std):
# accuracy: 0.2245 ± 0.0057
# balanced_acc: 0.4434 ± 0.0043
#
# per-class precision/recall/f1:
# 4T1: precision 0.1053 ± 0.0017, recall 0.7312 ± 0.0141, f1 0.1840 ± 0.0030
# 4T2: precision 0.8098 ± 0.0066, recall 0.1556 ± 0.0086, f1 0.2610 ± 0.0123
# Averaged confusion matrix (mean over folds):
# [[ 3198.8  1175.8]
#  [27186.6  5010.8]]
# Confusion matrix std (over folds):
# [[ 82.9323  61.3593]
#  [251.4769 283.0268]]
# Running experiment: quartic_galois_lr_poly_normalized
# Data: quartic_galois_lr_poly_normalized, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8800, balanced_acc=0.5003
# Fold 2/5: acc=0.8796, balanced_acc=0.5015
# Fold 3/5: acc=0.8838, balanced_acc=0.5011
# Fold 4/5: acc=0.8786, balanced_acc=0.5002
# Fold 5/5: acc=0.8809, balanced_acc=0.5009
# Averaged classification report (mean ± std):
# accuracy: 0.8806 ± 0.0018
# balanced_acc: 0.5008 ± 0.0005
#
# per-class precision/recall/f1:
# 4T1: precision 1.0000 ± 0.0000, recall 0.0016 ± 0.0009, f1 0.0032 ± 0.0018
# 4T2: precision 0.8806 ± 0.0018, recall 1.0000 ± 0.0000, f1 0.9365 ± 0.0010
# Averaged confusion matrix (mean over folds):
# [[7.0000e+00 4.3676e+03]
#  [0.0000e+00 3.2197e+04]]
# Confusion matrix std (over folds):
# [[ 4.0497 64.4161]
#  [ 0.     63.0479]]

# %%
# Distribution of polynomial coefficients
df_quartic_4T1 = df_quartic_galois.filter(pl.col("galois_label") == "4T1")
df_quartic_4T2 = df_quartic_galois.filter(pl.col("galois_label") == "4T2")
for i in range(4):
    print(f"c_{i}:")
    print(f"Mean: 4T1: {df_quartic_4T1[f'c_{i}'].mean()}, 4T2: {df_quartic_4T2[f'c_{i}'].mean()}")
    print(f"Mediean: 4T1: {df_quartic_4T1[f'c_{i}'].median()}, 4T2: {df_quartic_4T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 4T1: 102882526443.64673, 4T2: 62525821.141129404
# Mediean: 4T1: 2094672.0, 4T2: 96727.0
# c_1:
# Mean: 4T1: -11064534.074703973, 4T2: 77.18341232521881
# Mediean: 4T1: 0.0, 4T2: 0.0
# c_2:
# Mean: 4T1: -40876.83107026928, 4T2: -464.29426599663327
# Mediean: 4T1: -189.0, 4T2: -52.0
# c_3:
# Mean: 4T1: -0.5991862113107485, 4T2: -0.528899849056135
# Mediean: 4T1: -1.0, 4T2: 0.0

# %%
del df_quartic_galois, df_quartic_4T1, df_quartic_4T2

# %% [markdown]
# ### Nonic
#
# - `9T1`: $C_9$
# - `9T2`: $C_3^2$

# %%
df_nonic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_9_galois.csv")

# %%
df_stats(df_nonic_galois, "galois_label")
# Out:
# Number of rows: 1266
# Number of columns: 10012
# Head: shape: (5, 10_012)
# ┌─────────────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label               ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---                 ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str                 ┆ i64  ┆ str          ┆ i64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═════════════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 9.9.16983563041.1   ┆ 8    ┆ 9T1          ┆ -1  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.31381059609.1   ┆ 8    ┆ 9T1          ┆ -1  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.62523502209.1   ┆ 8    ┆ 9T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.567869252041.1  ┆ 8    ┆ 9T2          ┆ 8   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.2565164201769.1 ┆ 8    ┆ 9T2          ┆ -53 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# └─────────────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬─────┬──────────┐
# │ galois_label ┆ len ┆ percent  │
# │ ---          ┆ --- ┆ ---      │
# │ str          ┆ u32 ┆ f64      │
# ╞══════════════╪═════╪══════════╡
# │ 9T1          ┆ 284 ┆ 0.224329 │
# │ 9T2          ┆ 982 ┆ 0.775671 │
# └──────────────┴─────┴──────────┘

# %%
run_experiments(df_nonic_galois, "nonic_galois", ["9T1", "9T2"], current_dir, [3])
# Out:
# Running experiment: nonic_galois_dt_zc_1000
# Data: nonic_galois_dt_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=1.0000, balanced_acc=1.0000
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 1.0000 ± 0.0000
#
# per-class precision/recall/f1:
# 9T1: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# 9T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[ 56.8   0. ]
#  [  0.  196.4]]
# Confusion matrix std (over folds):
# [[8.1339 0.    ]
#  [0.     8.2849]]
# Running experiment: nonic_galois_dt_zc_1000_cb
# Data: nonic_galois_dt_zc_1000_cb, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=1.0000, balanced_acc=1.0000
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 1.0000 ± 0.0000
#
# per-class precision/recall/f1:
# 9T1: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# 9T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[ 56.8   0. ]
#  [  0.  196.4]]
# Confusion matrix std (over folds):
# [[8.1339 0.    ]
#  [0.     8.2849]]
# Running experiment: nonic_galois_dt_zc_1000_prime
# Data: nonic_galois_dt_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9291, balanced_acc=0.8823
# Fold 2/5: acc=0.9170, balanced_acc=0.8553
# Fold 3/5: acc=0.9170, balanced_acc=0.8987
# Fold 4/5: acc=0.9289, balanced_acc=0.9023
# Fold 5/5: acc=0.9328, balanced_acc=0.8913
# Averaged classification report (mean ± std):
# accuracy: 0.9250 ± 0.0066
# balanced_acc: 0.8860 ± 0.0168
#
# per-class precision/recall/f1:
# 9T1: precision 0.8427 ± 0.0378, recall 0.8157 ± 0.0421, f1 0.8276 ± 0.0216
# 9T2: precision 0.9475 ± 0.0125, recall 0.9562 ± 0.0123, f1 0.9517 ± 0.0051
# Averaged confusion matrix (mean over folds):
# [[ 46.4  10.4]
#  [  8.6 187.8]]
# Confusion matrix std (over folds):
# [[7.6315 2.5768]
#  [2.4166 8.2801]]
# Running experiment: nonic_galois_dt_zc_1000_prime_power
# Data: nonic_galois_dt_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=1.0000, balanced_acc=1.0000
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 1.0000 ± 0.0000
#
# per-class precision/recall/f1:
# 9T1: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# 9T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[ 56.8   0. ]
#  [  0.  196.4]]
# Confusion matrix std (over folds):
# [[8.1339 0.    ]
#  [0.     8.2849]]
# Running experiment: nonic_galois_dt_poly
# Data: nonic_galois_dt_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9528, balanced_acc=0.9484
# Fold 2/5: acc=0.8972, balanced_acc=0.8607
# Fold 3/5: acc=0.9289, balanced_acc=0.9064
# Fold 4/5: acc=0.9605, balanced_acc=0.9374
# Fold 5/5: acc=0.9684, balanced_acc=0.9553
# Averaged classification report (mean ± std):
# accuracy: 0.9415 ± 0.0258
# balanced_acc: 0.9216 ± 0.0348
#
# per-class precision/recall/f1:
# 9T1: precision 0.8619 ± 0.0674, recall 0.8838 ± 0.0538, f1 0.8718 ± 0.0529
# 9T2: precision 0.9648 ± 0.0181, recall 0.9594 ± 0.0212, f1 0.9620 ± 0.0170
# Averaged confusion matrix (mean over folds):
# [[ 50.    6.8]
#  [  8.  188.4]]
# Confusion matrix std (over folds):
# [[6.5422 3.4293]
#  [4.1473 8.309 ]]
# Running experiment: nonic_galois_lr_zc_1000
# Data: nonic_galois_lr_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9724, balanced_acc=0.9314
# Fold 2/5: acc=0.9763, balanced_acc=0.9483
# Fold 3/5: acc=0.9842, balanced_acc=0.9720
# Fold 4/5: acc=0.9565, balanced_acc=0.9258
# Fold 5/5: acc=0.9684, balanced_acc=0.9553
# Averaged classification report (mean ± std):
# accuracy: 0.9716 ± 0.0092
# balanced_acc: 0.9466 ± 0.0167
#
# per-class precision/recall/f1:
# 9T1: precision 0.9724 ± 0.0390, recall 0.9001 ± 0.0370, f1 0.9336 ± 0.0193
# 9T2: precision 0.9710 ± 0.0138, recall 0.9930 ± 0.0089, f1 0.9818 ± 0.0063
# Averaged confusion matrix (mean over folds):
# [[ 51.    5.8]
#  [  1.4 195. ]]
# Confusion matrix std (over folds):
# [[6.6332 2.6382]
#  [1.8547 7.5631]]
# Mean: 0.020319401995967108
# Median: 0.001296528577796885
# Std: 0.04359000153221903
# Top 30: [0.62649897 0.52685149 0.23636825 0.16286767 0.14539445 0.14260262
#  0.1345407  0.13103806 0.12665407 0.1123294  0.11209747 0.1108713
#  0.10391342 0.0948559  0.09477952 0.08827555 0.08177068 0.08122129
#  0.07982693 0.07762427 0.0762541  0.07400908 0.07138567 0.06884342
#  0.06851387 0.06660417 0.0637997  0.06119779 0.05776373 0.05725094]
# Top 30 indices: [215 999  63 247 512 124   7 583  26 423 232 471 183 135 432 882 231 350
#  535 620 658 700 391 966 998 447 511 663 711 295]
# Bottom 30: [-0.50069657 -0.17734673 -0.15750781 -0.15326747 -0.15288565 -0.15075797
#  -0.14631629 -0.14390066 -0.1429829  -0.139972   -0.13900182 -0.13870632
#  -0.13033746 -0.12576584 -0.12382023 -0.12333334 -0.12300706 -0.11519794
#  -0.11287014 -0.11247242 -0.11083242 -0.11060014 -0.11045872 -0.1092471
#  -0.10782204 -0.10559374 -0.10543197 -0.10522913 -0.10512515 -0.10386501]
# Bottom 30 indices: [624 198 255 366 568 940 676 618 199 240 460 750 946 928 190 551 990 982
#  106 742 242 612 292 752 250 834 520 808 320 522]
# Mean: 0.21322588483479765
# Median: 0.1345407045234856
# Std: 0.20473911398774125
# Running experiment: nonic_galois_lr_zc_1000_normalized
# Data: nonic_galois_lr_zc_1000_normalized, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8071, balanced_acc=0.6811
# Fold 2/5: acc=0.7668, balanced_acc=0.6367
# Fold 3/5: acc=0.7589, balanced_acc=0.6718
# Fold 4/5: acc=0.7628, balanced_acc=0.6596
# Fold 5/5: acc=0.8300, balanced_acc=0.7101
# Averaged classification report (mean ± std):
# accuracy: 0.7851 ± 0.0284
# balanced_acc: 0.6719 ± 0.0242
#
# per-class precision/recall/f1:
# 9T1: precision 0.5257 ± 0.0416, recall 0.4652 ± 0.0472, f1 0.4913 ± 0.0291
# 9T2: precision 0.8491 ± 0.0315, recall 0.8786 ± 0.0229, f1 0.8632 ± 0.0216
# Averaged confusion matrix (mean over folds):
# [[ 26.2  30.6]
#  [ 23.8 172.6]]
# Confusion matrix std (over folds):
# [[3.1241 6.2801]
#  [4.3081 9.5624]]
# Mean: 0.15507768955956125
# Median: 0.07045892178775004
# Std: 0.2541239522899602
# Top 30: [1.98661376 1.89056084 1.85617455 1.81172368 1.77424563 1.62859903
#  1.60001793 1.57726456 1.56160019 1.52048334 1.50688249 1.31838864
#  1.25073022 1.23602123 1.12714579 1.1128574  1.10699946 0.97315662
#  0.92899315 0.88457127 0.88457127 0.85808241 0.81203206 0.8086825
#  0.80488104 0.79751082 0.79171674 0.77522412 0.77167524 0.74502195]
# Top 30 indices: [391  26 836   7 998 455 215 247 124 638 823 962 663  55 295 407 583 980
#  151 967  87 512  12 567 855 332 711 620 423 887]
# Bottom 30: [-1.30356602 -1.27161066 -1.04270215 -1.01115313 -0.80276791 -0.76372487
#  -0.68553467 -0.67246384 -0.61323023 -0.59921307 -0.58477393 -0.57632069
#  -0.56715564 -0.55921634 -0.53635879 -0.5341034  -0.52462177 -0.49991093
#  -0.4847211  -0.46517092 -0.44742922 -0.43409091 -0.43409091 -0.42963946
#  -0.40989492 -0.40938986 -0.4048586  -0.40084234 -0.38952936 -0.38952936]
# Bottom 30 indices: [212 110 320  56 290   2 716  86  48 806 904 816 240 940 196 236  68 128
#  848 752 366 866  50 834 248 742 304 542  32 362]
# Mean: 0.9028291568460567
# Median: 0.5921861749121765
# Std: 0.7460994111836633
# Running experiment: nonic_galois_lr_zc_1000_cb
# Data: nonic_galois_lr_zc_1000_cb, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9606, balanced_acc=0.9020
# Fold 2/5: acc=0.9565, balanced_acc=0.9112
# Fold 3/5: acc=0.9605, balanced_acc=0.9153
# Fold 4/5: acc=0.9526, balanced_acc=0.9143
# Fold 5/5: acc=0.9684, balanced_acc=0.9130
# Averaged classification report (mean ± std):
# accuracy: 0.9597 ± 0.0052
# balanced_acc: 0.9112 ± 0.0048
#
# per-class precision/recall/f1:
# 9T1: precision 0.9959 ± 0.0082, recall 0.8233 ± 0.0098, f1 0.9014 ± 0.0062
# 9T2: precision 0.9513 ± 0.0077, recall 0.9990 ± 0.0021, f1 0.9745 ± 0.0042
# Averaged confusion matrix (mean over folds):
# [[ 46.8  10. ]
#  [  0.2 196.2]]
# Confusion matrix std (over folds):
# [[6.9685 1.2649]
#  [0.4    8.3283]]
# Running experiment: nonic_galois_lr_zc_1000_prime
# Data: nonic_galois_lr_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.7165, balanced_acc=0.5437
# Fold 2/5: acc=0.7233, balanced_acc=0.5480
# Fold 3/5: acc=0.7470, balanced_acc=0.5874
# Fold 4/5: acc=0.7312, balanced_acc=0.5981
# Fold 5/5: acc=0.7668, balanced_acc=0.5616
# Averaged classification report (mean ± std):
# accuracy: 0.7370 ± 0.0180
# balanced_acc: 0.5677 ± 0.0215
#
# per-class precision/recall/f1:
# 9T1: precision 0.3788 ± 0.0901, recall 0.2613 ± 0.0287, f1 0.3073 ± 0.0479
# 9T2: precision 0.8041 ± 0.0234, recall 0.8742 ± 0.0223, f1 0.8373 ± 0.0135
# Averaged confusion matrix (mean over folds):
# [[ 15.   41.8]
#  [ 24.8 171.6]]
# Confusion matrix std (over folds):
# [[3.5777 4.9558]
#  [5.0359 6.2801]]
# Running experiment: nonic_galois_lr_zc_1000_prime_power
# Data: nonic_galois_lr_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9764, balanced_acc=0.9485
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9565, balanced_acc=0.9173
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9605, balanced_acc=0.9388
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9605, balanced_acc=0.9330
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9723, balanced_acc=0.9408
# Averaged classification report (mean ± std):
# accuracy: 0.9652 ± 0.0077
# balanced_acc: 0.9357 ± 0.0105
#
# per-class precision/recall/f1:
# 9T1: precision 0.9613 ± 0.0193, recall 0.8816 ± 0.0212, f1 0.9194 ± 0.0130
# 9T2: precision 0.9659 ± 0.0100, recall 0.9898 ± 0.0056, f1 0.9777 ± 0.0055
# Averaged confusion matrix (mean over folds):
# [[ 50.    6.8]
#  [  2.  194.4]]
# Confusion matrix std (over folds):
# [[6.7528 1.833 ]
#  [1.0954 8.309 ]]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Running experiment: nonic_galois_lr_poly
# Data: nonic_galois_lr_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8543, balanced_acc=0.6740
# Fold 2/5: acc=0.8498, balanced_acc=0.6845
# Fold 3/5: acc=0.8340, balanced_acc=0.6912
# Fold 4/5: acc=0.7984, balanced_acc=0.6534
# Fold 5/5: acc=0.8893, balanced_acc=0.7295
# Averaged classification report (mean ± std):
# accuracy: 0.8452 ± 0.0295
# balanced_acc: 0.6865 ± 0.0250
#
# per-class precision/recall/f1:
# 9T1: precision 0.8328 ± 0.0546, recall 0.3965 ± 0.0508, f1 0.5344 ± 0.0455
# 9T2: precision 0.8471 ± 0.0331, recall 0.9765 ± 0.0101, f1 0.9069 ± 0.0198
# Averaged confusion matrix (mean over folds):
# [[ 22.2  34.6]
#  [  4.6 191.8]]
# Confusion matrix std (over folds):
# [[1.9391 7.4189]
#  [1.9596 8.5182]]
# Running experiment: nonic_galois_lr_poly_normalized
# Data: nonic_galois_lr_poly_normalized, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8780, balanced_acc=0.7034
# Fold 2/5: acc=0.8577, balanced_acc=0.6897
# Fold 3/5: acc=0.8419, balanced_acc=0.6728
# Fold 4/5: acc=0.7984, balanced_acc=0.6357
# Fold 5/5: acc=0.8972, balanced_acc=0.7343
# Averaged classification report (mean ± std):
# accuracy: 0.8546 ± 0.0337
# balanced_acc: 0.6872 ± 0.0327
#
# per-class precision/recall/f1:
# 9T1: precision 0.9569 ± 0.0381, recall 0.3793 ± 0.0679, f1 0.5386 ± 0.0674
# 9T2: precision 0.8454 ± 0.0381, recall 0.9950 ± 0.0045, f1 0.9136 ± 0.0215
# Averaged confusion matrix (mean over folds):
# [[ 21.   35.8]
#  [  1.  195.4]]
# Confusion matrix std (over folds):
# [[1.0954 9.0421]
#  [0.8944 7.7614]]

# %%
# Distribution of polynomial coefficients
df_nonic_9T1 = df_nonic_galois.filter(pl.col("galois_label") == "9T1")
df_nonic_9T2 = df_nonic_galois.filter(pl.col("galois_label") == "9T2")
for i in range(9):
    print(f"c_{i}:")
    print(f"Mean: 9T1: {df_nonic_9T1[f'c_{i}'].mean()}, 9T2: {df_nonic_9T2[f'c_{i}'].mean()}")
    print(f"Mediean: 9T1: {df_nonic_9T1[f'c_{i}'].median()}, 9T2: {df_nonic_9T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 9T1: -447118227.8169014, 9T2: -1466653860.4256618
# Mediean: 9T1: -198468.5, 9T2: -54243.5
# c_1:
# Mean: 9T1: 811066533.2464789, 9T2: -843469234.919552
# Mediean: 9T1: 8149986.0, 9T2: -1031126.0
# c_2:
# Mean: 9T1: -49031122.795774646, 9T2: -120032764.83910386
# Mediean: 9T1: -50715.0, 9T2: -1921468.0
# c_3:
# Mean: 9T1: -24216259.570422534, 9T2: -9416349.268839104
# Mediean: 9T1: -4621031.0, 9T2: -912550.0
# c_4:
# Mean: 9T1: 442437.2042253521, 9T2: 615257.00101833
# Mediean: 9T1: 12357.5, 9T2: 60875.0
# c_5:
# Mean: 9T1: 201120.14084507042, 9T2: 110125.82790224033
# Mediean: 9T1: 88884.0, 9T2: 35194.0
# c_6:
# Mean: 9T1: -1294.443661971831, 9T2: -840.7861507128309
# Mediean: 9T1: -211.0, 9T2: -346.0
# c_7:
# Mean: 9T1: -732.3415492957746, 9T2: -462.0641547861507
# Mediean: 9T1: -657.0, 9T2: -340.0
# c_8:
# Mean: 9T1: -0.4471830985915493, 9T2: -0.8462321792260692
# Mediean: 9T1: 0.0, 9T2: 0.0

# %%
del df_nonic_galois, df_nonic_9T1, df_nonic_9T2
