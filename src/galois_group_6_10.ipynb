# %% [markdown]
# ### Classifying Galois group of Sextic and Decic extensions

# %%
from utils import *

current_dir = globals()['_dh'][0]

# %% [markdown]
# ### Sextic
#
# - `6T1`: $C_6$
# - `6T2`: $S_3$

# %%
schema = {f"c_{i}": pl.Float64 for i in range(6)}
df_sextic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_6_galois.csv", schema_overrides=schema)

# %%
df_stats(df_sextic_galois, "galois_label")
# Out:
# Number of rows: 157168
# Number of columns: 10009
# Head: shape: (5, 10_009)
# ┌─────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label       ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---         ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str         ┆ i64  ┆ str          ┆ f64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 6.0.12167.1 ┆ 2    ┆ 6T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.16807.1 ┆ 2    ┆ 6T1          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.19683.1 ┆ 2    ┆ 6T1          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.21296.1 ┆ 2    ┆ 6T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.29791.1 ┆ 2    ┆ 6T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# └─────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬────────┬──────────┐
# │ galois_label ┆ len    ┆ percent  │
# │ ---          ┆ ---    ┆ ---      │
# │ str          ┆ u32    ┆ f64      │
# ╞══════════════╪════════╪══════════╡
# │ 6T1          ┆ 21146  ┆ 0.134544 │
# │ 6T2          ┆ 136022 ┆ 0.865456 │
# └──────────────┴────────┴──────────┘

# %%
run_experiments(df_sextic_galois, "sextic_galois", ["6T1", "6T2"], current_dir, [2, 3])
# Out:
# Running experiment: sextic_galois_dt_zc_1000
# Data: sextic_galois_dt_zc_1000, a
# Train: (125734, 1000)
# Test (galois_label): (31434, 1000)
#               precision    recall  f1-score   support
#
#          6T1     0.9545    0.9682    0.9613      4117
#          6T2     0.9952    0.9930    0.9941     27317
#
#     accuracy                         0.9898     31434
#    macro avg     0.9748    0.9806    0.9777     31434
# weighted avg     0.9899    0.9898    0.9898     31434
#
# balanced ACC: 0.9806126691694448
# Confusion matrix
# Running experiment: sextic_galois_dt_zc_1000_sq_cb
# Data: sextic_galois_dt_zc_1000_sq_cb, a
# Train: (125734, 46)
# Test (galois_label): (31434, 46)
#               precision    recall  f1-score   support
#
#          6T1     0.9683    0.9806    0.9744      4117
#          6T2     0.9971    0.9952    0.9961     27317
#
#     accuracy                         0.9933     31434
#    macro avg     0.9827    0.9879    0.9853     31434
# weighted avg     0.9933    0.9933    0.9933     31434
#
# balanced ACC: 0.9878681096149723
# Confusion matrix
# Running experiment: sextic_galois_dt_zc_1000_prime
# Data: sextic_galois_dt_zc_1000_prime, a_p
# Train: (125734, 168)
# Test (galois_label): (31434, 168)
#               precision    recall  f1-score   support
#
#          6T1     0.5934    0.6908    0.6384      4117
#          6T2     0.9522    0.9287    0.9403     27317
#
#     accuracy                         0.8975     31434
#    macro avg     0.7728    0.8097    0.7893     31434
# weighted avg     0.9052    0.8975    0.9007     31434
#
# balanced ACC: 0.8097233775663271
# Confusion matrix
# Running experiment: sextic_galois_dt_zc_10000_prime
# Data: sextic_galois_dt_zc_10000_prime, a_p
# Train: (125734, 1229)
# Test (galois_label): (31434, 1229)
#               precision    recall  f1-score   support
#
#          6T1     0.5980    0.6801    0.6364      4117
#          6T2     0.9508    0.9311    0.9408     27317
#
#     accuracy                         0.8982     31434
#    macro avg     0.7744    0.8056    0.7886     31434
# weighted avg     0.9046    0.8982    0.9010     31434
#
# balanced ACC: 0.8056060232702369
# Confusion matrix
# Running experiment: sextic_galois_dt_zc_1000_prime_power
# Data: sextic_galois_dt_zc_1000_prime_power, a_pp
# Train: (125734, 193)
# Test (galois_label): (31434, 193)
#               precision    recall  f1-score   support
#
#          6T1     0.9563    0.9721    0.9641      4117
#          6T2     0.9958    0.9933    0.9945     27317
#
#     accuracy                         0.9905     31434
#    macro avg     0.9760    0.9827    0.9793     31434
# weighted avg     0.9906    0.9905    0.9906     31434
#
# balanced ACC: 0.9826839570096015
# Confusion matrix
# Running experiment: sextic_galois_dt_poly
# Data: sextic_galois_dt_poly, c
# Train: (125734, 6)
# Test (galois_label): (31434, 6)
#               precision    recall  f1-score   support
#
#          6T1     0.9087    0.9041    0.9064      4117
#          6T2     0.9856    0.9863    0.9859     27317
#
#     accuracy                         0.9755     31434
#    macro avg     0.9471    0.9452    0.9461     31434
# weighted avg     0.9755    0.9755    0.9755     31434
#
# balanced ACC: 0.9451826218056147
# Confusion matrix
# Running experiment: sextic_galois_lr_zc_1000
# Data: sextic_galois_lr_zc_1000, a
# Train: (125734, 1000)
# Test (galois_label): (31434, 1000)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          6T1     0.9565    0.9300    0.9431      4117
#          6T2     0.9895    0.9936    0.9916     27317
#
#     accuracy                         0.9853     31434
#    macro avg     0.9730    0.9618    0.9673     31434
# weighted avg     0.9852    0.9853    0.9852     31434
#
# balanced ACC: 0.9618382450952855
# Confusion matrix
# Mean: 0.12651817318930889
# Median: 0.014286133086598648
# Std: 0.3858491948654344
# Top 30: [3.6976252  2.8008921  2.20399678 2.1981774  2.08159235 1.95325402
#  1.8278024  1.32763794 1.26376899 1.08122372 1.06729026 1.06109287
#  0.97934866 0.86362962 0.84871757 0.83090037 0.78543295 0.72795193
#  0.70020102 0.64271172 0.62480796 0.51451373 0.49387912 0.4915257
#  0.46130338 0.46076217 0.45845942 0.45470006 0.45152759 0.44840013]
# Top 30 indices: [  3  15 124  35  24 107  99  51 199 511  11  27 123  43 195 115  75  91
#   67  19 728 383 187 163 171 960 840 528 391   2]
# Bottom 30: [-3.92733552 -3.8027458  -3.6755093  -2.35091945 -2.23861281 -1.88009001
#  -1.83206453 -1.78546638 -1.77228874 -1.63821331 -1.56514983 -1.52711686
#  -1.43872218 -1.33346516 -1.31845695 -1.24812312 -1.23190156 -1.19597585
#  -1.07987166 -1.06657877 -1.03112831 -0.96508311 -0.95744604 -0.94393144
#  -0.93686274 -0.90249364 -0.8608333  -0.80546218 -0.77253834 -0.77215949]
# Bottom 30 indices: [ 49   0   4  53   7  28  22  30  16  12  97  18  10 624  63 143 255  39
#   61  57 242  37  81  80  93  45  85 431  95 121]
# Mean: 0.7719634136854816
# Median: 0.4456525843640534
# Std: 0.8653421837344761
# Running experiment: sextic_galois_lr_zc_1000_sq_cb
# Data: sextic_galois_lr_zc_1000_sq_cb, a
# Train: (125734, 46)
# Test (galois_label): (31434, 46)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          6T1     0.9261    0.8003    0.8586      4117
#          6T2     0.9705    0.9904    0.9803     27317
#
#     accuracy                         0.9655     31434
#    macro avg     0.9483    0.8954    0.9195     31434
# weighted avg     0.9647    0.9655    0.9644     31434
#
# balanced ACC: 0.8953561745385231
# Confusion matrix
# Running experiment: sextic_galois_lr_zc_1000_prime
# Data: sextic_galois_lr_zc_1000_prime, a_p
# Train: (125734, 168)
# Test (galois_label): (31434, 168)
#               precision    recall  f1-score   support
#
#          6T1     0.9052    0.3964    0.5514      4117
#          6T2     0.9161    0.9937    0.9534     27317
#
#     accuracy                         0.9155     31434
#    macro avg     0.9106    0.6951    0.7524     31434
# weighted avg     0.9147    0.9155    0.9007     31434
#
# balanced ACC: 0.6950726555923109
# Confusion matrix
# Running experiment: sextic_galois_lr_zc_1000_prime_power
# Data: sextic_galois_lr_zc_1000_prime_power, a_pp
# Train: (125734, 193)
# Test (galois_label): (31434, 193)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          6T1     0.9578    0.9264    0.9418      4117
#          6T2     0.9890    0.9938    0.9914     27317
#
#     accuracy                         0.9850     31434
#    macro avg     0.9734    0.9601    0.9666     31434
# weighted avg     0.9849    0.9850    0.9849     31434
#
# balanced ACC: 0.9601263519771186
# Confusion matrix
# Running experiment: sextic_galois_lr_poly
# Data: sextic_galois_lr_poly, c
# Train: (125734, 6)
# Test (galois_label): (31434, 6)
#               precision    recall  f1-score   support
#
#          6T1     0.1400    0.9910    0.2453      4117
#          6T2     0.9838    0.0822    0.1518     27317
#
#     accuracy                         0.2012     31434
#    macro avg     0.5619    0.5366    0.1985     31434
# weighted avg     0.8733    0.2012    0.1640     31434
#
# balanced ACC: 0.5366163682702307
# Confusion matrix
# Running experiment: sextic_galois_lr_poly_normalized
# Data: sextic_galois_lr_poly_normalized, c
# Train: (125734, 6)
# Test (galois_label): (31434, 6)
#               precision    recall  f1-score   support
#
#          6T1     0.9631    0.0634    0.1190      4117
#          6T2     0.8763    0.9996    0.9339     27317
#
#     accuracy                         0.8770     31434
#    macro avg     0.9197    0.5315    0.5264     31434
# weighted avg     0.8876    0.8770    0.8272     31434
#
# balanced ACC: 0.5315148020271608
# Confusion matrix

# %%
# Distribution of polynomial coefficients
df_sextic_6T1 = df_sextic_galois.filter(pl.col("galois_label") == "6T1")
df_sextic_6T2 = df_sextic_galois.filter(pl.col("galois_label") == "6T2")
for i in range(6):
    print(f"c_{i}:")
    print(f"Mean: 6T1: {df_sextic_6T1[f'c_{i}'].mean()}, 6T2: {df_sextic_6T2[f'c_{i}'].mean()}")
    print(f"Mediean: 6T1: {df_sextic_6T1[f'c_{i}'].median()}, 6T2: {df_sextic_6T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 6T1: 4.397122621387055e+17, 6T2: 2217750846.4364367
# Mediean: 6T1: 148653.5, 6T2: 715682.0
# c_1:
# Mean: 6T1: -366062326578648.8, 6T2: -2416301.8775933306
# Mediean: 6T1: -2341.0, 6T2: 0.0
# c_2:
# Mean: 6T1: 76265344713.3534, 6T2: 195193.72077311022
# Mediean: 6T1: 133956.0, 6T2: 23128.5
# c_3:
# Mean: 6T1: 9103683.460465336, 6T2: 864.370065136522
# Mediean: 6T1: -2.0, 6T2: 0.0
# c_4:
# Mean: 6T1: -3102.2026387969354, 6T2: -137.8802840716943
# Mediean: 6T1: -77.0, 6T2: -50.0
# c_5:
# Mean: 6T1: -1.0549040007566444, 6T2: -0.7421887635823616
# Mediean: 6T1: -1.0, 6T2: 0.0

# %%
del df_sextic_galois, df_sextic_6T1, df_sextic_6T2

# %% [markdown]
# ### Decic
#
# - `10T1`: $C_{10}$
# - `10T2`: $D_5$

# %%
schema = {f"c_{i}": pl.Float64 for i in range(10)}
df_decic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_10_galois.csv", schema_overrides=schema)

# %%
df_stats(df_decic_galois, "galois_label")
# Out:
# Number of rows: 5476
# Number of columns: 10013
# Head: shape: (5, 10_013)
# ┌────────────────────┬──────┬──────────────┬──────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label              ┆ rank ┆ galois_label ┆ c_0  ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---                ┆ ---  ┆ ---          ┆ ---  ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str                ┆ i64  ┆ str          ┆ f64  ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞════════════════════╪══════╪══════════════╪══════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 10.0.229345007.1   ┆ 4    ┆ 10T2         ┆ 1.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.2357947691.1  ┆ 4    ┆ 10T1         ┆ 1.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.3077056399.1  ┆ 4    ┆ 10T2         ┆ 1.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.11592740743.1 ┆ 4    ┆ 10T2         ┆ 9.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.23863536599.2 ┆ 4    ┆ 10T2         ┆ 32.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# └────────────────────┴──────┴──────────────┴──────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬──────┬──────────┐
# │ galois_label ┆ len  ┆ percent  │
# │ ---          ┆ ---  ┆ ---      │
# │ str          ┆ u32  ┆ f64      │
# ╞══════════════╪══════╪══════════╡
# │ 10T1         ┆ 1854 ┆ 0.338568 │
# │ 10T2         ┆ 3622 ┆ 0.661432 │
# └──────────────┴──────┴──────────┘

# %%
run_experiments(df_decic_galois, "decic_galois", ["10T1", "10T2"], current_dir, [2, 5])
# Out:
# Running experiment: decic_galois_dt_zc_1000
# Data: decic_galois_dt_zc_1000, a
# Train: (4380, 1000)
# Test (galois_label): (1096, 1000)
#               precision    recall  f1-score   support
#
#         10T1     0.9562    0.9763    0.9661       380
#         10T2     0.9873    0.9763    0.9817       716
#
#     accuracy                         0.9763      1096
#    macro avg     0.9717    0.9763    0.9739      1096
# weighted avg     0.9765    0.9763    0.9763      1096
#
# balanced ACC: 0.9762863863569539
# Confusion matrix
# Running experiment: decic_galois_dt_zc_10000_sq_qu
# Data: decic_galois_dt_zc_10000_sq_qu, a
# Train: (4380, 114)
# Test (galois_label): (1096, 114)
#               precision    recall  f1-score   support
#
#         10T1     0.9818    0.9947    0.9882       380
#         10T2     0.9972    0.9902    0.9937       716
#
#     accuracy                         0.9918      1096
#    macro avg     0.9895    0.9925    0.9910      1096
# weighted avg     0.9919    0.9918    0.9918      1096
#
# balanced ACC: 0.9924801528962071
# Confusion matrix
# Running experiment: decic_galois_dt_zc_10000_prime
# Data: decic_galois_dt_zc_10000_prime, a_p
# Train: (4380, 1229)
# Test (galois_label): (1096, 1229)
#               precision    recall  f1-score   support
#
#         10T1     0.8020    0.8316    0.8165       380
#         10T2     0.9088    0.8911    0.8999       716
#
#     accuracy                         0.8704      1096
#    macro avg     0.8554    0.8613    0.8582      1096
# weighted avg     0.8718    0.8704    0.8710      1096
#
# balanced ACC: 0.8613201999411938
# Confusion matrix
# Running experiment: decic_galois_dt_zc_10000_prime_power
# Data: decic_galois_dt_zc_10000_prime_power, a_pp
# Train: (4380, 1280)
# Test (galois_label): (1096, 1280)
#               precision    recall  f1-score   support
#
#         10T1     0.9741    0.9895    0.9817       380
#         10T2     0.9944    0.9860    0.9902       716
#
#     accuracy                         0.9872      1096
#    macro avg     0.9842    0.9878    0.9860      1096
# weighted avg     0.9873    0.9872    0.9872      1096
#
# balanced ACC: 0.9877536018817994
# Confusion matrix
# Running experiment: decic_galois_dt_poly
# Data: decic_galois_dt_poly, c
# Train: (4380, 6)
# Test (galois_label): (1096, 6)
#               precision    recall  f1-score   support
#
#         10T1     0.7883    0.8132    0.8005       380
#         10T2     0.8991    0.8841    0.8915       716
#
#     accuracy                         0.8595      1096
#    macro avg     0.8437    0.8486    0.8460      1096
# weighted avg     0.8607    0.8595    0.8600      1096
#
# balanced ACC: 0.8486180535136725
# Confusion matrix
# Running experiment: decic_galois_lr_zc_1000
# Data: decic_galois_lr_zc_1000, a
# Train: (4380, 1000)
# Test (galois_label): (1096, 1000)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF F,G EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#         10T1     0.8825    0.9289    0.9051       380
#         10T2     0.9612    0.9344    0.9476       716
#
#     accuracy                         0.9325      1096
#    macro avg     0.9219    0.9317    0.9264      1096
# weighted avg     0.9339    0.9325    0.9329      1096
#
# balanced ACC: 0.931652455160247
# Confusion matrix
# Mean: 0.06892176943222064
# Median: 0.0369980805033121
# Std: 0.0968391078243552
# Top 30: [1.0862672  0.83624003 0.81932498 0.66572297 0.38420941 0.38089253
#  0.38001722 0.37887146 0.37826276 0.37343987 0.36831621 0.36454572
#  0.33619907 0.32474856 0.32061053 0.31972684 0.3160482  0.31412698
#  0.30716943 0.29189947 0.28747077 0.28382057 0.27464776 0.27367155
#  0.25417338 0.2476959  0.24415448 0.24096371 0.23729665 0.23584751]
# Top 30 indices: [ 48  31  24 287 544 276 971 315 520  82 862  99 408 820 910 979 760 808
#  234 242 398 882 280 558 826 763 684 906 798 187]
# Bottom 30: [-0.60736884 -0.59110018 -0.53461274 -0.47886167 -0.44752113 -0.44041064
#  -0.39424165 -0.37266404 -0.32584453 -0.31923735 -0.28266696 -0.27943393
#  -0.27263316 -0.27122374 -0.26733895 -0.26561382 -0.25089205 -0.24035725
#  -0.23459612 -0.21179412 -0.20996483 -0.20799533 -0.20563443 -0.20485343
#  -0.20483874 -0.19778153 -0.19704775 -0.18594508 -0.18354262 -0.17453541]
# Bottom 30 indices: [ 94 124  30  10  16  18 342 127 647  22 488 672  66  28 630  26 431  12
#  400 304 410 363 462 843 838 294 175 718 394 150]
# Mean: 0.2084487425848745
# Median: 0.11567156273182187
# Std: 0.25168426719082115
# Running experiment: decic_galois_lr_zc_10000_sq_qu
# Data: decic_galois_lr_zc_10000_sq_qu, a
# Train: (4380, 114)
# Test (galois_label): (1096, 114)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#         10T1     0.9457    0.9632    0.9544       380
#         10T2     0.9803    0.9707    0.9754       716
#
#     accuracy                         0.9681      1096
#    macro avg     0.9630    0.9669    0.9649      1096
# weighted avg     0.9683    0.9681    0.9681      1096
#
# balanced ACC: 0.9669141428991472
# Confusion matrix
# Running experiment: decic_galois_lr_zc_10000_prime
# Data: decic_galois_lr_zc_10000_prime, a_p
# Train: (4380, 1229)
# Test (galois_label): (1096, 1229)
#               precision    recall  f1-score   support
#
#         10T1     0.8905    0.9421    0.9156       380
#         10T2     0.9683    0.9385    0.9532       716
#
#     accuracy                         0.9398      1096
#    macro avg     0.9294    0.9403    0.9344      1096
# weighted avg     0.9413    0.9398    0.9402      1096
#
# balanced ACC: 0.9403263745957071
# Confusion matrix
# Running experiment: decic_galois_lr_zc_10000_prime_power
# Data: decic_galois_lr_zc_10000_prime_power, a_pp
# Train: (4380, 1280)
# Test (galois_label): (1096, 1280)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#         10T1     0.9767    0.9921    0.9843       380
#         10T2     0.9958    0.9874    0.9916       716
#
#     accuracy                         0.9891      1096
#    macro avg     0.9862    0.9898    0.9880      1096
# weighted avg     0.9892    0.9891    0.9891      1096
#
# balanced ACC: 0.98976771537783
# Confusion matrix
# Running experiment: decic_galois_lr_poly
# Data: decic_galois_lr_poly, c
# Train: (4380, 6)
# Test (galois_label): (1096, 6)
#               precision    recall  f1-score   support
#
#         10T1     0.3935    0.9526    0.5569       380
#         10T2     0.8977    0.2207    0.3543       716
#
#     accuracy                         0.4745      1096
#    macro avg     0.6456    0.5867    0.4556      1096
# weighted avg     0.7229    0.4745    0.4245      1096
#
# balanced ACC: 0.5866509850044105
# Confusion matrix
# Running experiment: decic_galois_lr_poly_normalized
# Data: decic_galois_lr_poly_normalized, c
# Train: (4380, 6)
# Test (galois_label): (1096, 6)
#               precision    recall  f1-score   support
#
#         10T1     0.0000    0.0000    0.0000       380
#         10T2     0.6533    1.0000    0.7903       716
#
#     accuracy                         0.6533      1096
#    macro avg     0.3266    0.5000    0.3951      1096
# weighted avg     0.4268    0.6533    0.5163      1096
#
# balanced ACC: 0.5
# Confusion matrix
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Distribution of polynomial coefficients
df_decic_10T1 = df_decic_galois.filter(pl.col("galois_label") == "10T1")
df_decic_10T2 = df_decic_galois.filter(pl.col("galois_label") == "10T2")
for i in range(6):
    print(f"c_{i}:")
    print(f"Mean: 10T1: {df_decic_10T1[f'c_{i}'].mean()}, 10T2: {df_decic_10T2[f'c_{i}'].mean()}")
    print(f"Mediean: 10T1: {df_decic_10T1[f'c_{i}'].median()}, 10T2: {df_decic_10T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 10T1: 3.2751681160246415e+19, 10T2: 8067610.266703479
# Mediean: 10T1: 183633.0, 10T2: 812144.0
# c_1:
# Mean: 10T1: -1.0067062842059324e+18, 10T2: -202378.10049696302
# Mediean: 10T1: -495351.0, 10T2: 0.0
# c_2:
# Mean: 10T1: 7746535577696627.0, 10T2: 769342.605466593
# Mediean: 10T1: 14831547.0, 10T2: 129930.5
# c_3:
# Mean: 10T1: 36695895596564.53, 10T2: -6039.120375483159
# Mediean: 10T1: 0.0, 10T2: 0.0
# c_4:
# Mean: 10T1: -569812488131.5636, 10T2: 28733.506902263944
# Mediean: 10T1: 778.5, 10T2: 13503.5
# c_5:
# Mean: 10T1: -270990336.93419635, 10T2: -1047.7020982882386
# Mediean: 10T1: -8424.0, 10T2: 0.0

# %%
del df_decic_galois, df_decic_10T1, df_decic_10T2
