# %% [markdown]
# ### Classifying Galois group of octic extensions

# %%
from utils import *

current_dir = globals()['_dh'][0]

# %% [markdown]
# ### Octic
#
# - `8T1`: $C_8$
# - `8T2`: $C_4 \times C_2$
# - `8T3`: $C_2^3$
# - `8T4`: $D_4$
# - `8T5`: $Q_8$

# %%
schema = {f"c_{i}": pl.Float64 for i in range(8)}
df_octic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_8_galois.csv", schema_overrides=schema)

# %%
df_stats(df_octic_galois, "galois_label")
# Out:
# Number of rows: 114576
# Number of columns: 10011
# Head: shape: (5, 10_011)
# ┌───────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label         ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---           ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str           ┆ i64  ┆ str          ┆ f64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 8.0.1265625.1 ┆ 3    ┆ 8T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# │ 8.0.1750329.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 20      │
# │ 8.0.2313441.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 4       │
# │ 8.0.2560000.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 8.0.2985984.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# └───────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (5, 3)
# ┌──────────────┬───────┬──────────┐
# │ galois_label ┆ len   ┆ percent  │
# │ ---          ┆ ---   ┆ ---      │
# │ str          ┆ u32   ┆ f64      │
# ╞══════════════╪═══════╪══════════╡
# │ 8T1          ┆ 6206  ┆ 0.054165 │
# │ 8T2          ┆ 19550 ┆ 0.170629 │
# │ 8T3          ┆ 10767 ┆ 0.093973 │
# │ 8T4          ┆ 27796 ┆ 0.242599 │
# │ 8T5          ┆ 50257 ┆ 0.438635 │
# └──────────────┴───────┴──────────┘

# %% [markdown]
# ### Abelian extensions ($C_8$, $C_4 \times C_2$, $C_2^3$)

# %%
df_octic_abelian = df_octic_galois.filter(pl.col("galois_label").is_in(["8T1", "8T2", "8T3"]))
df_stats(df_octic_abelian, "galois_label")
# Out:
# Number of rows: 36523
# Number of columns: 10011
# Head: shape: (5, 10_011)
# ┌────────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label          ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---            ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str            ┆ i64  ┆ str          ┆ f64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞════════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 8.0.1265625.1  ┆ 3    ┆ 8T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# │ 8.0.4000000.1  ┆ 3    ┆ 8T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 5       │
# │ 8.0.5308416.1  ┆ 3    ┆ 8T3          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 10      │
# │ 8.0.12960000.1 ┆ 3    ┆ 8T3          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 9       │
# │ 8.0.16777216.1 ┆ 3    ┆ 8T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# └────────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (3, 3)
# ┌──────────────┬───────┬──────────┐
# │ galois_label ┆ len   ┆ percent  │
# │ ---          ┆ ---   ┆ ---      │
# │ str          ┆ u32   ┆ f64      │
# ╞══════════════╪═══════╪══════════╡
# │ 8T1          ┆ 6206  ┆ 0.16992  │
# │ 8T2          ┆ 19550 ┆ 0.535279 │
# │ 8T3          ┆ 10767 ┆ 0.294801 │
# └──────────────┴───────┴──────────┘

# %%
run_experiments(df_octic_abelian, "octic_ab_galois", ["8T1", "8T2", "8T3"], current_dir, [2])
# Out:
# Running experiment: octic_ab_dt_zc_1000
# Data: octic_ab_dt_zc_1000, a
# Train: (29218, 1000)
# Test (galois_label): (7305, 1000)
#               precision    recall  f1-score   support
#
#          8T1     0.9706    0.9668    0.9687      1264
#          8T2     0.9891    0.9904    0.9898      3855
#          8T3     1.0000    1.0000    1.0000      2186
#
#     accuracy                         0.9892      7305
#    macro avg     0.9866    0.9857    0.9861      7305
# weighted avg     0.9892    0.9892    0.9892      7305
#
# Confusion matrix
# Running experiment: octic_ab_dt_zc_10000_sq
# Data: octic_ab_dt_zc_10000_sq, a
# Train: (29218, 99)
# Test (galois_label): (7305, 99)
#               precision    recall  f1-score   support
#
#          8T1     0.9890    0.9960    0.9925      1264
#          8T2     0.9987    0.9964    0.9975      3855
#          8T3     1.0000    1.0000    1.0000      2186
#
#     accuracy                         0.9974      7305
#    macro avg     0.9959    0.9975    0.9967      7305
# weighted avg     0.9974    0.9974    0.9974      7305
#
# Confusion matrix
# Running experiment: octic_ab_dt_zc_10000_prime
# Data: octic_ab_dt_zc_10000_prime, a_p
# Train: (29218, 1229)
# Test (galois_label): (7305, 1229)
#               precision    recall  f1-score   support
#
#          8T1     0.7261    0.7025    0.7141      1264
#          8T2     0.8802    0.8898    0.8849      3855
#          8T3     0.9204    0.9199    0.9202      2186
#
#     accuracy                         0.8664      7305
#    macro avg     0.8422    0.8374    0.8397      7305
# weighted avg     0.8655    0.8664    0.8659      7305
#
# Confusion matrix
# Running experiment: octic_ab_dt_poly
# Data: octic_ab_dt_poly, c
# Train: (29218, 8)
# Test (galois_label): (7305, 8)
#               precision    recall  f1-score   support
#
#          8T1     0.8405    0.8299    0.8352      1264
#          8T2     0.7948    0.7966    0.7957      3855
#          8T3     0.7291    0.7315    0.7303      2186
#
#     accuracy                         0.7829      7305
#    macro avg     0.7882    0.7860    0.7871      7305
# weighted avg     0.7831    0.7829    0.7830      7305
#
# Confusion matrix
# Running experiment: octic_ab_lr_zc_1000
# Data: octic_ab_lr_zc_1000, a
# Train: (29218, 1000)
# Test (galois_label): (7305, 1000)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          8T1     0.8758    0.8426    0.8589      1264
#          8T2     0.9398    0.9432    0.9415      3855
#          8T3     0.9649    0.9799    0.9723      2186
#
#     accuracy                         0.9368      7305
#    macro avg     0.9268    0.9219    0.9242      7305
# weighted avg     0.9362    0.9368    0.9364      7305
#
# Confusion matrix
# Multiclass classification detected. Analyzing each class separately.
# Class 1 (8T1):
# Mean: 0.04586714536989547
# Median: 0.020574184690203286
# Std: 0.08905002375732785
# Top 30: [0.91284404 0.90386756 0.78093462 0.75745965 0.54430891 0.53056924
#  0.51992606 0.44303182 0.43861317 0.43818459 0.40355835 0.38870932
#  0.34743456 0.32332882 0.32226962 0.30604335 0.3036586  0.30211206
#  0.29203175 0.27670255 0.27037019 0.26573736 0.20030216 0.19202857
#  0.18809586 0.18784612 0.1862725  0.17837083 0.17621383 0.17515831]
# Top 30 indices: [ 30  22  18  28  26  37  16 107 728  10  57  53   0   1  12  43  76  33
#   61  15  45  86  32 342  51 121   2  21 146 255]
# Bottom 30: [-0.83254076 -0.68214064 -0.42841067 -0.41357085 -0.35973886 -0.3499168
#  -0.3040981  -0.29104176 -0.2886271  -0.28651956 -0.27950585 -0.2679775
#  -0.26530029 -0.2581431  -0.24634417 -0.2084897  -0.18667364 -0.17196701
#  -0.14437413 -0.14124337 -0.13129367 -0.12355652 -0.12188426 -0.11674628
#  -0.11560817 -0.11406667 -0.11055017 -0.11039688 -0.10671296 -0.10370341]
# Bottom 30 indices: [ 80 242  48  99  71   4 191 528 840  35 960 360  24   8  63 215 288 195
#  359  74 103 120 971 713 511  55 168  87 263  69]
# Class 2 (8T2):
# Mean: 0.031051115024533782
# Median: 0.014701348985607127
# Std: 0.06617162774537441
# Top 30: [1.11953698 0.60564268 0.49146341 0.27706762 0.21559422 0.1957492
#  0.18802339 0.18624287 0.14460546 0.13828973 0.13765035 0.13528384
#  0.13063688 0.12658073 0.12407014 0.12131532 0.12025714 0.11899311
#  0.11671586 0.1150095  0.1149105  0.11065807 0.10996518 0.1069883
#  0.10673467 0.10539108 0.10208877 0.10015358 0.09981088 0.09806192]
# Top 30 indices: [ 80 242   4 191  63 323  44 624  19  79 155 215  91  75  71  60  51  55
#  713 149  15   9  69 190  67  38 272  95 131 103]
# Bottom 30: [-0.64306888 -0.57289965 -0.46719953 -0.43768072 -0.43054898 -0.31334436
#  -0.30894895 -0.27897466 -0.26406139 -0.25817099 -0.24639402 -0.22565162
#  -0.21304309 -0.19277881 -0.18002319 -0.16414103 -0.1518873  -0.14256992
#  -0.13036385 -0.1299252  -0.12971405 -0.12710306 -0.12611382 -0.12503137
#  -0.12085458 -0.12058505 -0.11838853 -0.11757706 -0.11738459 -0.11278406]
# Bottom 30 indices: [ 26  35 124 107 728  99  53  86  57  22  37  30   2 134   1  10  61  92
#   11  45 121  77 188  33  56 299   8 224 461 195]
# Class 3 (8T3):
# Mean: 0.04815512323365491
# Median: 0.02656139723046465
# Std: 0.07745283848771009
# Top 30: [0.85941922 0.72691521 0.38772182 0.37653164 0.33447395 0.31289153
#  0.30453024 0.28475107 0.2753607  0.26355301 0.23566872 0.23361558
#  0.21988441 0.21814944 0.19126423 0.18570369 0.15008089 0.14852751
#  0.13553876 0.12723495 0.12680071 0.12332866 0.12294977 0.12186908
#  0.11702467 0.11605791 0.11384856 0.11072971 0.11039843 0.10650795]
# Top 30 indices: [ 35  99  48   8 124 840  24 195 360 528  71 960 288 224 134  74 299 359
#    6 188 971 391 675 483 506 763  56 235 440 599]
# Bottom 30: [-0.80452568 -0.68719242 -0.67475804 -0.64569657 -0.50482014 -0.39161305
#  -0.34950578 -0.33722232 -0.308353   -0.30028947 -0.29426689 -0.28995717
#  -0.28699622 -0.28417522 -0.27404355 -0.26915012 -0.24681775 -0.22232196
#  -0.21722664 -0.21271085 -0.20709232 -0.19632972 -0.18256021 -0.17708069
#  -0.16109675 -0.15966537 -0.15521454 -0.15373847 -0.15242805 -0.15154712]
# Bottom 30 indices: [ 28  30  18  22  16  15  76 323  51   0  12  43  80  37  10  44 342 190
#   38 381 624 146  54  33  64 196 223 108 166  72]
# Multiclass classification detected. Analyzing each class separately.
# Class 1 (8T1):
# Mean: 0.20287055173493668
# Median: 0.1735626575706784
# Std: 0.16982206362559008
# Class 2 (8T2):
# Mean: 0.14198015459855953
# Median: 0.055762809584668574
# Std: 0.22149056264049738
# Class 3 (8T3):
# Mean: 0.22530985480810006
# Median: 0.21262087721451142
# Std: 0.19202770237295153
# Running experiment: octic_ab_lr_zc_10000_sq
# Data: octic_ab_lr_zc_10000_sq, a
# Train: (29218, 99)
# Test (galois_label): (7305, 99)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          8T1     0.8690    0.4881    0.6251      1264
#          8T2     0.8185    0.9149    0.8640      3855
#          8T3     0.8880    0.9286    0.9079      2186
#
#     accuracy                         0.8452      7305
#    macro avg     0.8585    0.7772    0.7990      7305
# weighted avg     0.8481    0.8452    0.8358      7305
#
# Confusion matrix
# Running experiment: octic_ab_lr_zc_10000_prime
# Data: octic_ab_lr_zc_10000_prime, a_p
# Train: (29218, 1229)
# Test (galois_label): (7305, 1229)
#               precision    recall  f1-score   support
#
#          8T1     0.5815    0.4628    0.5154      1264
#          8T2     0.7315    0.7790    0.7545      3855
#          8T3     0.7571    0.7598    0.7584      2186
#
#     accuracy                         0.7185      7305
#    macro avg     0.6900    0.6672    0.6761      7305
# weighted avg     0.7132    0.7185    0.7143      7305
#
# Confusion matrix
# Running experiment: octic_ab_lr_poly
# Data: octic_ab_lr_poly, c
# Train: (29218, 8)
# Test (galois_label): (7305, 8)
#               precision    recall  f1-score   support
#
#          8T1     0.1702    0.5356    0.2583      1264
#          8T2     0.0000    0.0000    0.0000      3855
#          8T3     0.2838    0.4318    0.3425      2186
#
#     accuracy                         0.2219      7305
#    macro avg     0.1514    0.3225    0.2003      7305
# weighted avg     0.1144    0.2219    0.1472      7305
#
# Confusion matrix

# %%
# Distribution of polynomial coefficients
df_octic_8T1 = df_octic_abelian.filter(pl.col("galois_label") == "8T1")
df_octic_8T2 = df_octic_abelian.filter(pl.col("galois_label") == "8T2")
df_octic_8T3 = df_octic_abelian.filter(pl.col("galois_label") == "8T3")
for i in range(8):
    print(f"c_{i}:")
    print(f"Mean: 8T1: {df_octic_8T1[f'c_{i}'].mean()}, 8T2: {df_octic_8T2[f'c_{i}'].mean()}, 8T3: {df_octic_8T3[f'c_{i}'].mean()}")
    print(f"Mediean: 8T1: {df_octic_8T1[f'c_{i}'].median()}, 8T2: {df_octic_8T2[f'c_{i}'].median()}, 8T3: {df_octic_8T3[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 8T1: 185498321443501.66, 8T2: 2999051643106.9077, 8T3: 1453364920.8085818
# Mediean: 8T1: 46465054380.0, 8T2: 6744055.5, 8T3: 101761.0
# c_1:
# Mean: 8T1: -114211143290.35869, 8T2: 2186861446.657238, 8T3: -792534.9413021269
# Mediean: 8T1: 0.0, 8T2: 0.0, 8T3: 0.0
# c_2:
# Mean: 8T1: 2650789649.924589, 8T2: -1002900168.5658312, 8T3: 110248.61001207393
# Mediean: 8T1: 54947.5, 8T2: 0.0, 8T3: 0.0
# c_3:
# Mean: 8T1: -36938752.27183371, 8T2: 226818.4966240409, 8T3: -9197.664251880748
# Mediean: 8T1: 0.0, 8T2: 0.0, 8T3: 0.0
# c_4:
# Mean: 8T1: 27404159.338059943, 8T2: 1130280.6475191815, 8T3: 17957.48314293675
# Mediean: 8T1: 5192965.5, 8T2: 15248.5, 8T3: 1967.0
# c_5:
# Mean: 8T1: 8853.387205929745, 8T2: 531.4540153452685, 8T3: 16.423887805331105
# Mediean: 8T1: 0.0, 8T2: 0.0, 8T3: 0.0
# c_6:
# Mean: 8T1: -1566.8013213019658, 8T2: -72.11038363171356, 8T3: -15.027862914460853
# Mediean: 8T1: -77.0, 8T2: 0.0, 8T3: 0.0
# c_7:
# Mean: 8T1: -0.4892039961327747, 8T2: -1.1140153452685422, 8T3: -1.7941859385158354
# Mediean: 8T1: 0.0, 8T2: 0.0, 8T3: -1.0

# %% [markdown]
# ### Nonabelian extensions ($D_4, Q_8$)

# %%
df_octic_nonabelian = df_octic_galois.filter(pl.col("galois_label").is_in(["8T4", "8T5"]))
df_stats(df_octic_nonabelian, "galois_label")
# Out:
# Number of rows: 78053
# Number of columns: 10011
# Head: shape: (5, 10_011)
# ┌───────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label         ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---           ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str           ┆ i64  ┆ str          ┆ f64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 8.0.1750329.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 20      │
# │ 8.0.2313441.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 4       │
# │ 8.0.2560000.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 8.0.2985984.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# │ 8.0.4194304.1 ┆ 3    ┆ 8T4          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 10      │
# └───────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬───────┬──────────┐
# │ galois_label ┆ len   ┆ percent  │
# │ ---          ┆ ---   ┆ ---      │
# │ str          ┆ u32   ┆ f64      │
# ╞══════════════╪═══════╪══════════╡
# │ 8T4          ┆ 27796 ┆ 0.356117 │
# │ 8T5          ┆ 50257 ┆ 0.643883 │
# └──────────────┴───────┴──────────┘

# %%
run_experiments(df_octic_nonabelian, "octic_nab_galois", ["8T4", "8T5"], current_dir, [2])
# Out:
# Running experiment: octic_nab_dt_zc_1000
# Data: octic_nab_dt_zc_1000, a
# Train: (62442, 1000)
# Test (galois_label): (15611, 1000)
#               precision    recall  f1-score   support
#
#          8T4     0.9824    0.9836    0.9830      5489
#          8T5     0.9911    0.9904    0.9908     10122
#
#     accuracy                         0.9880     15611
#    macro avg     0.9867    0.9870    0.9869     15611
# weighted avg     0.9880    0.9880    0.9880     15611
#
# Confusion matrix
# Running experiment: octic_nab_dt_zc_10000_sq
# Data: octic_nab_dt_zc_10000_sq, a
# Train: (62442, 99)
# Test (galois_label): (15611, 99)
#               precision    recall  f1-score   support
#
#          8T4     0.9913    0.9927    0.9920      5489
#          8T5     0.9960    0.9953    0.9957     10122
#
#     accuracy                         0.9944     15611
#    macro avg     0.9937    0.9940    0.9938     15611
# weighted avg     0.9944    0.9944    0.9944     15611
#
# Confusion matrix
# Running experiment: octic_nab_dt_zc_10000_prime
# Data: octic_nab_dt_zc_10000_prime, a_p
# Train: (62442, 1229)
# Test (galois_label): (15611, 1229)
#               precision    recall  f1-score   support
#
#          8T4     0.7893    0.8003    0.7948      5489
#          8T5     0.8909    0.8841    0.8875     10122
#
#     accuracy                         0.8547     15611
#    macro avg     0.8401    0.8422    0.8411     15611
# weighted avg     0.8552    0.8547    0.8549     15611
#
# Confusion matrix
# Running experiment: octic_nab_dt_poly
# Data: octic_nab_dt_poly, c
# Train: (62442, 8)
# Test (galois_label): (15611, 8)
#               precision    recall  f1-score   support
#
#          8T4     0.9801    0.9792    0.9797      5489
#          8T5     0.9887    0.9892    0.9890     10122
#
#     accuracy                         0.9857     15611
#    macro avg     0.9844    0.9842    0.9843     15611
# weighted avg     0.9857    0.9857    0.9857     15611
#
# Confusion matrix
# Running experiment: octic_nab_lr_zc_1000
# Data: octic_nab_lr_zc_1000, a
# Train: (62442, 1000)
# Test (galois_label): (15611, 1000)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          8T4     0.9684    0.9617    0.9651      5489
#          8T5     0.9793    0.9830    0.9812     10122
#
#     accuracy                         0.9755     15611
#    macro avg     0.9739    0.9724    0.9731     15611
# weighted avg     0.9755    0.9755    0.9755     15611
#
# Confusion matrix
# Mean: 0.05228835149245792
# Median: 0.013232275807464632
# Std: 0.19438691925754184
# Top 30: [2.38712214 2.26975321 2.12195639 1.96203303 1.92336538 1.87333493
#  1.79317918 1.60998142 0.8891836  0.8220802  0.65940131 0.55019503
#  0.46361623 0.45589103 0.39289566 0.36157214 0.32600874 0.3235029
#  0.31480529 0.27320309 0.2455081  0.24432408 0.24169615 0.23538412
#  0.21309562 0.20976873 0.20605438 0.20527931 0.17808405 0.16639694]
# Top 30 indices: [ 28  30  16  12  22   0   4  18  10   1  37   3  33  25  19  50  17   9
#   21   7  35 255 342  71   8 624  76  44  15  43]
# Bottom 30: [-0.84947961 -0.79717791 -0.53359576 -0.50819523 -0.45259632 -0.44886116
#  -0.43876444 -0.43625309 -0.43131622 -0.37332751 -0.32675176 -0.27245727
#  -0.19013354 -0.18455299 -0.18190828 -0.15612719 -0.1528108  -0.14391202
#  -0.14300862 -0.13572071 -0.13070982 -0.12814311 -0.12743386 -0.12739626
#  -0.12479481 -0.11814717 -0.11758041 -0.10630728 -0.1026102  -0.09571625]
# Bottom 30 indices: [ 24  48 840 960 288 528 168 124  63 360 161 143  99  39 323  20  32 721
#   14  67  80 241 191 103 287 120 482 455 227 671]
# Mean: 0.25661477937447597
# Median: 0.19995113553158095
# Std: 0.22999268697608896
# Running experiment: octic_nab_lr_zc_10000_sq
# Data: octic_nab_lr_zc_10000_sq, a
# Train: (62442, 99)
# Test (galois_label): (15611, 99)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#          8T4     0.8139    0.6987    0.7519      5489
#          8T5     0.8482    0.9134    0.8796     10122
#
#     accuracy                         0.8379     15611
#    macro avg     0.8311    0.8060    0.8157     15611
# weighted avg     0.8362    0.8379    0.8347     15611
#
# Confusion matrix
# Running experiment: octic_nab_lr_zc_10000_prime
# Data: octic_nab_lr_zc_10000_prime, a_p
# Train: (62442, 1229)
# Test (galois_label): (15611, 1229)
#               precision    recall  f1-score   support
#
#          8T4     0.7506    0.6169    0.6772      5489
#          8T5     0.8105    0.8889    0.8479     10122
#
#     accuracy                         0.7932     15611
#    macro avg     0.7806    0.7529    0.7625     15611
# weighted avg     0.7895    0.7932    0.7879     15611
#
# Confusion matrix
# Running experiment: octic_nab_lr_poly
# Data: octic_nab_lr_poly, c
# Train: (62442, 8)
# Test (galois_label): (15611, 8)
#               precision    recall  f1-score   support
#
#          8T4     0.9967    0.1088    0.1961      5489
#          8T5     0.6741    0.9998    0.8053     10122
#
#     accuracy                         0.6865     15611
#    macro avg     0.8354    0.5543    0.5007     15611
# weighted avg     0.7875    0.6865    0.5911     15611
#
# Confusion matrix

# %%
# Distribution of polynomial coefficients
df_octic_8T4 = df_octic_nonabelian.filter(pl.col("galois_label") == "8T4")
df_octic_8T5 = df_octic_nonabelian.filter(pl.col("galois_label") == "8T5")
for i in range(8):
    print(f"c_{i}:")
    print(f"Mean: 8T4: {df_octic_8T4[f'c_{i}'].mean()}, 8T5: {df_octic_8T5[f'c_{i}'].mean()}")
    print(f"Mediean: 8T4: {df_octic_8T4[f'c_{i}'].median()}, 8T5: {df_octic_8T5[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 8T4: 130702863702.43967, 8T5: 2.2771680410218819e+18
# Mediean: 8T4: 119991.5, 8T5: 149325956010000.0
# c_1:
# Mean: 8T4: 546566100.2904735, 8T5: -230929356398.54468
# Mediean: 8T4: 0.0, 8T5: 0.0
# c_2:
# Mean: 8T4: -168533322.4195208, 8T5: -181112281516.8934
# Mediean: 8T4: 1770.0, 8T5: -1003804777.0
# c_3:
# Mean: 8T4: 2045386.814289826, 8T5: 113295687.8022763
# Mediean: 8T4: 0.0, 8T5: 0.0
# c_4:
# Mean: 8T4: 325375.0622391711, 8T5: 7887711449.999165
# Mediean: 8T4: 1671.5, 8T5: 768366612.0
# c_5:
# Mean: 8T4: 78.39825874226507, 8T5: 2358.378056788109
# Mediean: 8T4: 0.0, 8T5: 0.0
# c_6:
# Mean: 8T4: -104.58454453878255, 8T5: -8839.09284278807
# Mediean: 8T4: 4.0, 8T5: -12903.0
# c_7:
# Mean: 8T4: -1.2187365088501942, 8T5: -0.6178641781244404
# Mediean: 8T4: 0.0, 8T5: 0.0

# %% [markdown]
# ### Abelian vs Nonabelian

# %%
replace_dict = {
    "8T1": "abelian",
    "8T2": "abelian",
    "8T3": "abelian",
    "8T4": "nonabelian",
    "8T5": "nonabelian",
}
new_label_col = df_octic_galois["galois_label"].replace(replace_dict)
df_octic_ab_nab = df_octic_galois.clone()
df_octic_ab_nab = df_octic_ab_nab.replace_column(2, new_label_col)

# %%
df_stats(df_octic_ab_nab, "galois_label")
# Out:
# Number of rows: 114576
# Number of columns: 10011
# Head: shape: (5, 10_011)
# ┌───────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label         ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---           ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str           ┆ i64  ┆ str          ┆ f64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 8.0.1265625.1 ┆ 3    ┆ abelian      ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# │ 8.0.1750329.1 ┆ 3    ┆ nonabelian   ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 20      │
# │ 8.0.2313441.1 ┆ 3    ┆ nonabelian   ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 4       │
# │ 8.0.2560000.1 ┆ 3    ┆ nonabelian   ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 8.0.2985984.1 ┆ 3    ┆ nonabelian   ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 2       │
# └───────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬───────┬──────────┐
# │ galois_label ┆ len   ┆ percent  │
# │ ---          ┆ ---   ┆ ---      │
# │ str          ┆ u32   ┆ f64      │
# ╞══════════════╪═══════╪══════════╡
# │ abelian      ┆ 36523 ┆ 0.318767 │
# │ nonabelian   ┆ 78053 ┆ 0.681233 │
# └──────────────┴───────┴──────────┘

# %%
run_experiments(df_octic_ab_nab, "octic_ab_nab_galois", ["abelian", "nonabelian"], current_dir, [2])
# Out:
# Running experiment: octic_ab_nab_dt_zc_1000
# Data: octic_ab_nab_dt_zc_1000, a
# Train: (91660, 1000)
# Test (galois_label): (22916, 1000)
#               precision    recall  f1-score   support
#
#      abelian     0.9457    0.9464    0.9461      7386
#   nonabelian     0.9745    0.9742    0.9743     15530
#
#     accuracy                         0.9652     22916
#    macro avg     0.9601    0.9603    0.9602     22916
# weighted avg     0.9652    0.9652    0.9652     22916
#
# Confusion matrix
# Running experiment: octic_ab_nab_dt_zc_10000_sq
# Data: octic_ab_nab_dt_zc_10000_sq, a
# Train: (91660, 99)
# Test (galois_label): (22916, 99)
#               precision    recall  f1-score   support
#
#      abelian     0.9727    0.9783    0.9755      7386
#   nonabelian     0.9897    0.9869    0.9883     15530
#
#     accuracy                         0.9842     22916
#    macro avg     0.9812    0.9826    0.9819     22916
# weighted avg     0.9842    0.9842    0.9842     22916
#
# Confusion matrix
# Running experiment: octic_ab_nab_dt_zc_10000_prime
# Data: octic_ab_nab_dt_zc_10000_prime, a_p
# Train: (91660, 1229)
# Test (galois_label): (22916, 1229)
#               precision    recall  f1-score   support
#
#      abelian     0.7359    0.7705    0.7528      7386
#   nonabelian     0.8884    0.8685    0.8783     15530
#
#     accuracy                         0.8369     22916
#    macro avg     0.8121    0.8195    0.8156     22916
# weighted avg     0.8392    0.8369    0.8379     22916
#
# Confusion matrix
# Running experiment: octic_ab_nab_dt_poly
# Data: octic_ab_nab_dt_poly, c
# Train: (91660, 8)
# Test (galois_label): (22916, 8)
#               precision    recall  f1-score   support
#
#      abelian     0.7426    0.7536    0.7481      7386
#   nonabelian     0.8820    0.8758    0.8789     15530
#
#     accuracy                         0.8364     22916
#    macro avg     0.8123    0.8147    0.8135     22916
# weighted avg     0.8371    0.8364    0.8367     22916
#
# Confusion matrix
# Running experiment: octic_ab_nab_lr_zc_1000
# Data: octic_ab_nab_lr_zc_1000, a
# Train: (91660, 1000)
# Test (galois_label): (22916, 1000)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#      abelian     0.6724    0.5060    0.5774      7386
#   nonabelian     0.7898    0.8827    0.8337     15530
#
#     accuracy                         0.7613     22916
#    macro avg     0.7311    0.6944    0.7055     22916
# weighted avg     0.7519    0.7613    0.7511     22916
#
# Confusion matrix
# Mean: 0.01547450864142253
# Median: 0.0049722864019218094
# Std: 0.03851659621690011
# Top 30: [0.47942436 0.45323098 0.37857668 0.30454884 0.2801142  0.24145556
#  0.22975847 0.181653   0.17390757 0.15352702 0.14700478 0.13756871
#  0.12200608 0.11960108 0.11938766 0.11931907 0.11307545 0.11058354
#  0.1095494  0.10950152 0.09512719 0.09394688 0.08530184 0.08485878
#  0.08066231 0.07840616 0.07076547 0.07013227 0.06602627 0.06373226]
# Top 30 indices: [  4  16  12   8  28  30  17 242 127  22  19  79  61  18  64  25  44  33
#  624   0 255  97  45  24  54   1   9  36 215 149]
# Bottom 30: [-0.37264441 -0.20447388 -0.19022499 -0.16103519 -0.12450436 -0.12338537
#  -0.11992543 -0.10285319 -0.10158311 -0.09882863 -0.09826645 -0.09340488
#  -0.08901318 -0.08200909 -0.07945205 -0.07882985 -0.06866452 -0.06735723
#  -0.06336498 -0.06308921 -0.05753182 -0.05666403 -0.05477574 -0.05198184
#  -0.05182747 -0.0505285  -0.04851237 -0.04727384 -0.04633183 -0.04559045]
# Bottom 30 indices: [124  26  15  71  39  63 288  80 168   7  53  87 960  35 511 840  73   2
#  103  55  50 728 528  32  99 319 360 101  58 120]
# Mean: 0.06480531234254926
# Median: 0.05422308912696491
# Std: 0.06401801835245438
# Running experiment: octic_ab_nab_lr_zc_10000_sq
# Data: octic_ab_nab_lr_zc_10000_sq, a
# Train: (91660, 99)
# Test (galois_label): (22916, 99)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#      abelian     0.7036    0.0816    0.1463      7386
#   nonabelian     0.6925    0.9836    0.8128     15530
#
#     accuracy                         0.6929     22916
#    macro avg     0.6981    0.5326    0.4795     22916
# weighted avg     0.6961    0.6929    0.5980     22916
#
# Confusion matrix
# Running experiment: octic_ab_nab_lr_zc_10000_prime
# Data: octic_ab_nab_lr_zc_10000_prime, a_p
# Train: (91660, 1229)
# Test (galois_label): (22916, 1229)
#               precision    recall  f1-score   support
#
#      abelian     0.6465    0.4532    0.5328      7386
#   nonabelian     0.7723    0.8822    0.8236     15530
#
#     accuracy                         0.7439     22916
#    macro avg     0.7094    0.6677    0.6782     22916
# weighted avg     0.7318    0.7439    0.7299     22916
#
# Confusion matrix
# Running experiment: octic_ab_nab_lr_poly
# Data: octic_ab_nab_lr_poly, c
# Train: (91660, 8)
# Test (galois_label): (22916, 8)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#      abelian     0.2773    0.0299    0.0540      7386
#   nonabelian     0.6761    0.9629    0.7944     15530
#
#     accuracy                         0.6622     22916
#    macro avg     0.4767    0.4964    0.4242     22916
# weighted avg     0.5475    0.6622    0.5558     22916
#
# Confusion matrix

# %%
# Distribution of polynomial coefficients
for i in range(8):
    print(f"c_{i}:")
    print(f"Mean: ab: {df_octic_abelian[f'c_{i}'].mean()}, nab: {df_octic_nonabelian[f'c_{i}'].mean()}")
    print(f"Mediean: ab: {df_octic_abelian[f'c_{i}'].median()}, nab: {df_octic_nonabelian[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: ab: 33125693149007.844, nab: 1.466229842166906e+18
# Mediean: ab: 3254416.0, nab: 765296896.0
# c_1:
# Mean: ab: -18236446819.854065, nab: -148496845902.11765
# Mediean: ab: 0.0, nab: 0.0
# c_2:
# Mean: ab: -86376000.91027571, nab: -116675137207.08345
# Mediean: ab: 0.0, nab: 2.0
# c_3:
# Mean: ab: -6157945.027544287, nab: 73677564.65182632
# Mediean: ab: 0.0, nab: 0.0
# c_4:
# Mean: ab: 5266833.166278783, nab: 5078879203.462237
# Mediean: ab: 11647.0, nab: 63708386.0
# c_5:
# Mean: ab: 1793.6884428989952, nab: 1546.4384969187604
# Mediean: ab: 0.0, nab: 0.0
# c_6:
# Mean: ab: -309.2607945678066, nab: -5728.5859736333005
# Mediean: ab: 0.0, nab: -29.0
# c_7:
# Mean: ab: -1.2083618541740822, nab: -0.8318450283781533
# Mediean: ab: 0.0, nab: 0.0

# %%
del df_octic_galois, df_octic_8T1, df_octic_8T2, df_octic_8T3, df_octic_8T4, df_octic_8T5
del df_octic_ab_nab, df_octic_abelian, df_octic_nonabelian
