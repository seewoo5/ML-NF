# %% [markdown]
# ### Classifying Galois group of Sextic and Decic extensions

# %%
from utils import *

current_dir = globals()['_dh'][0]

# %% [markdown]
# ### Sextic
#
# - `6T1`: $C_6$
# - `6T2`: $S_3$

# %%
schema = {f"c_{i}": pl.Float64 for i in range(6)}
df_sextic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_6_galois.csv", schema_overrides=schema)

# %%
df_stats(df_sextic_galois, "galois_label")
# Out:
# Number of rows: 157168
# Number of columns: 10009
# Head: shape: (5, 10_009)
# ┌─────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label       ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---         ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str         ┆ i64  ┆ str          ┆ f64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 6.0.12167.1 ┆ 2    ┆ 6T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.16807.1 ┆ 2    ┆ 6T1          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.19683.1 ┆ 2    ┆ 6T1          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.21296.1 ┆ 2    ┆ 6T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 6.0.29791.1 ┆ 2    ┆ 6T2          ┆ 1.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# └─────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬────────┬──────────┐
# │ galois_label ┆ len    ┆ percent  │
# │ ---          ┆ ---    ┆ ---      │
# │ str          ┆ u32    ┆ f64      │
# ╞══════════════╪════════╪══════════╡
# │ 6T1          ┆ 21146  ┆ 0.134544 │
# │ 6T2          ┆ 136022 ┆ 0.865456 │
# └──────────────┴────────┴──────────┘

# %%
run_experiments(df_sextic_galois, "sextic_galois", ["6T1", "6T2"], current_dir, [2, 3])
# Out:
# Running experiment: sextic_galois_dt_zc_1000
# Data: sextic_galois_dt_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9898, balanced_acc=0.9806
# Fold 2/5: acc=0.9899, balanced_acc=0.9800
# Fold 3/5: acc=0.9893, balanced_acc=0.9788
# Fold 4/5: acc=0.9895, balanced_acc=0.9792
# Fold 5/5: acc=0.9897, balanced_acc=0.9792
# Averaged classification report (mean ± std):
# accuracy: 0.9896 ± 0.0002
# balanced_acc: 0.9795 ± 0.0007
#
# per-class precision/recall/f1:
# 6T1: precision 0.9575 ± 0.0018, recall 0.9657 ± 0.0014, f1 0.9616 ± 0.0008
# 6T2: precision 0.9947 ± 0.0003, recall 0.9933 ± 0.0002, f1 0.9940 ± 0.0001
# Averaged confusion matrix (mean over folds):
# [[ 4084.2   145. ]
#  [  181.  27023.4]]
# Confusion matrix std (over folds):
# [[56.9821  7.5895]
#  [ 5.933  59.5134]]
# Running experiment: sextic_galois_dt_zc_1000_sq_cb
# Data: sextic_galois_dt_zc_1000_sq_cb, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9933, balanced_acc=0.9879
# Fold 2/5: acc=0.9931, balanced_acc=0.9844
# Fold 3/5: acc=0.9929, balanced_acc=0.9860
# Fold 4/5: acc=0.9924, balanced_acc=0.9849
# Fold 5/5: acc=0.9938, balanced_acc=0.9870
# Averaged classification report (mean ± std):
# accuracy: 0.9931 ± 0.0004
# balanced_acc: 0.9860 ± 0.0013
#
# per-class precision/recall/f1:
# 6T1: precision 0.9724 ± 0.0032, recall 0.9764 ± 0.0028, f1 0.9744 ± 0.0015
# 6T2: precision 0.9963 ± 0.0005, recall 0.9957 ± 0.0005, f1 0.9960 ± 0.0003
# Averaged confusion matrix (mean over folds):
# [[ 4129.2   100. ]
#  [  117.2 27087.2]]
# Confusion matrix std (over folds):
# [[52.7841 12.853 ]
#  [13.467  61.5578]]
# Running experiment: sextic_galois_dt_zc_1000_prime
# Data: sextic_galois_dt_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8975, balanced_acc=0.8097
# Fold 2/5: acc=0.8938, balanced_acc=0.7961
# Fold 3/5: acc=0.8966, balanced_acc=0.7996
# Fold 4/5: acc=0.8963, balanced_acc=0.8041
# Fold 5/5: acc=0.8990, balanced_acc=0.8096
# Averaged classification report (mean ± std):
# accuracy: 0.8966 ± 0.0017
# balanced_acc: 0.8038 ± 0.0054
#
# per-class precision/recall/f1:
# 6T1: precision 0.6033 ± 0.0069, recall 0.6769 ± 0.0111, f1 0.6379 ± 0.0063
# 6T2: precision 0.9488 ± 0.0022, recall 0.9308 ± 0.0013, f1 0.9397 ± 0.0010
# Averaged confusion matrix (mean over folds):
# [[ 2862.2  1367. ]
#  [ 1882.2 25322.2]]
# Confusion matrix std (over folds):
# [[42.6821 60.5343]
#  [38.9533 46.675 ]]
# Running experiment: sextic_galois_dt_zc_1000_prime_power
# Data: sextic_galois_dt_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9905, balanced_acc=0.9827
# Fold 2/5: acc=0.9900, balanced_acc=0.9805
# Fold 3/5: acc=0.9899, balanced_acc=0.9832
# Fold 4/5: acc=0.9907, balanced_acc=0.9822
# Fold 5/5: acc=0.9908, balanced_acc=0.9822
# Averaged classification report (mean ± std):
# accuracy: 0.9904 ± 0.0004
# balanced_acc: 0.9821 ± 0.0009
#
# per-class precision/recall/f1:
# 6T1: precision 0.9581 ± 0.0037, recall 0.9709 ± 0.0022, f1 0.9645 ± 0.0013
# 6T2: precision 0.9955 ± 0.0004, recall 0.9934 ± 0.0006, f1 0.9944 ± 0.0002
# Averaged confusion matrix (mean over folds):
# [[ 4106.    123.2]
#  [  179.4 27025. ]]
# Confusion matrix std (over folds):
# [[59.2115 10.0876]
#  [16.1567 61.0344]]
# Running experiment: sextic_galois_dt_poly
# Data: sextic_galois_dt_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9755, balanced_acc=0.9452
# Fold 2/5: acc=0.9759, balanced_acc=0.9482
# Fold 3/5: acc=0.9755, balanced_acc=0.9482
# Fold 4/5: acc=0.9743, balanced_acc=0.9436
# Fold 5/5: acc=0.9766, balanced_acc=0.9474
# Averaged classification report (mean ± std):
# accuracy: 0.9756 ± 0.0008
# balanced_acc: 0.9465 ± 0.0018
#
# per-class precision/recall/f1:
# 6T1: precision 0.9113 ± 0.0035, recall 0.9067 ± 0.0036, f1 0.9090 ± 0.0026
# 6T2: precision 0.9855 ± 0.0006, recall 0.9863 ± 0.0006, f1 0.9859 ± 0.0005
# Averaged confusion matrix (mean over folds):
# [[ 3834.8   394.4]
#  [  373.4 26831. ]]
# Confusion matrix std (over folds):
# [[58.6495 16.9304]
#  [16.0449 68.0559]]
# Running experiment: sextic_galois_lr_zc_1000
# Data: sextic_galois_lr_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9847, balanced_acc=0.9595
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9828, balanced_acc=0.9558
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9837, balanced_acc=0.9592
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9840, balanced_acc=0.9618
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9847, balanced_acc=0.9588
# Averaged classification report (mean ± std):
# accuracy: 0.9840 ± 0.0007
# balanced_acc: 0.9590 ± 0.0019
#
# per-class precision/recall/f1:
# 6T1: precision 0.9547 ± 0.0038, recall 0.9248 ± 0.0040, f1 0.9395 ± 0.0024
# 6T2: precision 0.9884 ± 0.0006, recall 0.9932 ± 0.0007, f1 0.9908 ± 0.0004
# Averaged confusion matrix (mean over folds):
# [[ 3911.4   317.8]
#  [  185.6 27018.8]]
# Confusion matrix std (over folds):
# [[65.0864 16.6781]
#  [17.8281 74.8636]]
# Mean: 0.12651817318930889
# Median: 0.014286133086598648
# Std: 0.3858491948654344
# Top 30: [3.6976252  2.8008921  2.20399678 2.1981774  2.08159235 1.95325402
#  1.8278024  1.32763794 1.26376899 1.08122372 1.06729026 1.06109287
#  0.97934866 0.86362962 0.84871757 0.83090037 0.78543295 0.72795193
#  0.70020102 0.64271172 0.62480796 0.51451373 0.49387912 0.4915257
#  0.46130338 0.46076217 0.45845942 0.45470006 0.45152759 0.44840013]
# Top 30 indices: [  3  15 124  35  24 107  99  51 199 511  11  27 123  43 195 115  75  91
#   67  19 728 383 187 163 171 960 840 528 391   2]
# Bottom 30: [-3.92733552 -3.8027458  -3.6755093  -2.35091945 -2.23861281 -1.88009001
#  -1.83206453 -1.78546638 -1.77228874 -1.63821331 -1.56514983 -1.52711686
#  -1.43872218 -1.33346516 -1.31845695 -1.24812312 -1.23190156 -1.19597585
#  -1.07987166 -1.06657877 -1.03112831 -0.96508311 -0.95744604 -0.94393144
#  -0.93686274 -0.90249364 -0.8608333  -0.80546218 -0.77253834 -0.77215949]
# Bottom 30 indices: [ 49   0   4  53   7  28  22  30  16  12  97  18  10 624  63 143 255  39
#   61  57 242  37  81  80  93  45  85 431  95 121]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Mean: 0.7719634136854816
# Median: 0.4456525843640534
# Std: 0.8653421837344761
# Running experiment: sextic_galois_lr_zc_1000_normalized
# Data: sextic_galois_lr_zc_1000_normalized, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9789, balanced_acc=0.9445
# Fold 2/5: acc=0.9768, balanced_acc=0.9401
# Fold 3/5: acc=0.9773, balanced_acc=0.9422
# Fold 4/5: acc=0.9776, balanced_acc=0.9455
# Fold 5/5: acc=0.9794, balanced_acc=0.9453
# Averaged classification report (mean ± std):
# accuracy: 0.9780 ± 0.0010
# balanced_acc: 0.9435 ± 0.0021
#
# per-class precision/recall/f1:
# 6T1: precision 0.9375 ± 0.0045, recall 0.8963 ± 0.0040, f1 0.9165 ± 0.0033
# 6T2: precision 0.9840 ± 0.0007, recall 0.9907 ± 0.0008, f1 0.9873 ± 0.0006
# Averaged confusion matrix (mean over folds):
# [[ 3790.8   438.4]
#  [  252.8 26951.6]]
# Confusion matrix std (over folds):
# [[59.9713 17.9399]
#  [20.7885 76.1383]]
# Mean: 0.6263495239106119
# Median: 0.08244932226820907
# Std: 1.5149175721677846
# Top 30: [14.40252988 12.02711261  7.82860632  7.3926915   6.85757136  6.25000788
#   5.52223914  4.84948902  4.3220762   4.21828126  4.03438383  3.99194371
#   3.76452042  3.68990548  3.5717022   3.55838583  3.42540772  3.32313647
#   3.22959516  3.19261151  3.12220119  3.09573395  3.07189567  3.02934117
#   2.92760611  2.84033203  2.79309823  2.78865181  2.70398104  2.68210258]
# Top 30 indices: [124  24   3 511 127  31  26  99  35 195 351 415 895 383 728 991  51 607
#  123 107 223 639  87  95 543  75 960 483 840 927]
# Bottom 30: [-20.86601124 -15.48770356  -9.54155624  -9.32354527  -6.59157931
#   -6.44787357  -6.03565261  -5.98815357  -5.9473844   -5.88124116
#   -5.16819551  -4.96394561  -4.83843624  -4.82241675  -4.70446088
#   -4.67791823  -4.63097591  -4.43207192  -4.35927846  -3.55376082
#   -3.49631524  -2.98921812  -2.9800502   -2.94327529  -2.92112222
#   -2.89605681  -2.83114724  -2.70170274  -2.65775578  -2.6039396 ]
# Bottom 30 indices: [624  15 242  63 495   4 111 303 399  47 175 207 463  79 143 271 367 431
#  783 335 971 191 447 485  30 687  28 655  22 975]
# Mean: 3.93578992720621
# Median: 2.4796598915873487
# Std: 4.24122390691052
# Running experiment: sextic_galois_lr_zc_1000_sq_cb
# Data: sextic_galois_lr_zc_1000_sq_cb, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9648, balanced_acc=0.8927
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9646, balanced_acc=0.8968
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9649, balanced_acc=0.8987
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9637, balanced_acc=0.8943
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9676, balanced_acc=0.9071
# Averaged classification report (mean ± std):
# accuracy: 0.9651 ± 0.0013
# balanced_acc: 0.8979 ± 0.0050
#
# per-class precision/recall/f1:
# 6T1: precision 0.9250 ± 0.0018, recall 0.8060 ± 0.0102, f1 0.8614 ± 0.0059
# 6T2: precision 0.9704 ± 0.0015, recall 0.9898 ± 0.0003, f1 0.9800 ± 0.0008
# Averaged confusion matrix (mean over folds):
# [[ 3408.8   820.4]
#  [  276.4 26928. ]]
# Confusion matrix std (over folds):
# [[71.8231 42.5516]
#  [ 8.7772 68.6586]]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Running experiment: sextic_galois_lr_zc_1000_prime
# Data: sextic_galois_lr_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9155, balanced_acc=0.6951
# Fold 2/5: acc=0.9139, balanced_acc=0.6953
# Fold 3/5: acc=0.9123, balanced_acc=0.6901
# Fold 4/5: acc=0.9112, balanced_acc=0.6902
# Fold 5/5: acc=0.9143, balanced_acc=0.6971
# Averaged classification report (mean ± std):
# accuracy: 0.9134 ± 0.0015
# balanced_acc: 0.6936 ± 0.0029
#
# per-class precision/recall/f1:
# 6T1: precision 0.9156 ± 0.0067, recall 0.3927 ± 0.0058, f1 0.5497 ± 0.0056
# 6T2: precision 0.9133 ± 0.0019, recall 0.9944 ± 0.0004, f1 0.9521 ± 0.0009
# Averaged confusion matrix (mean over folds):
# [[ 1660.8  2568.4]
#  [  153.  27051.4]]
# Confusion matrix std (over folds):
# [[24.1031 55.6834]
#  [11.8659 53.6082]]
# Running experiment: sextic_galois_lr_zc_1000_prime_power
# Data: sextic_galois_lr_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9851, balanced_acc=0.9602
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9844, balanced_acc=0.9580
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9848, balanced_acc=0.9609
# Fold 4/5: acc=0.9845, balanced_acc=0.9615
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9851, balanced_acc=0.9589
# Averaged classification report (mean ± std):
# accuracy: 0.9848 ± 0.0003
# balanced_acc: 0.9599 ± 0.0013
#
# per-class precision/recall/f1:
# 6T1: precision 0.9598 ± 0.0029, recall 0.9258 ± 0.0030, f1 0.9425 ± 0.0007
# 6T2: precision 0.9885 ± 0.0005, recall 0.9940 ± 0.0005, f1 0.9912 ± 0.0002
# Averaged confusion matrix (mean over folds):
# [[ 3915.6   313.6]
#  [  164.2 27040.2]]
# Confusion matrix std (over folds):
# [[62.4391 12.8312]
#  [13.3477 69.4187]]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Running experiment: sextic_galois_lr_poly
# Data: sextic_galois_lr_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.2012, balanced_acc=0.5366
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.3034, balanced_acc=0.4943
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.2974, balanced_acc=0.4657
# Fold 4/5: acc=0.2069, balanced_acc=0.5364
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.3021, balanced_acc=0.5013
# Averaged classification report (mean ± std):
# accuracy: 0.2622 ± 0.0475
# balanced_acc: 0.5069 ± 0.0270
#
# per-class precision/recall/f1:
# 6T1: precision 0.1358 ± 0.0074, recall 0.8415 ± 0.1245, f1 0.2336 ± 0.0154
# 6T2: precision 0.9048 ± 0.0647, recall 0.1722 ± 0.0735, f1 0.2797 ± 0.1044
# Averaged confusion matrix (mean over folds):
# [[ 3557.6   671.6]
#  [22520.6  4683.8]]
# Confusion matrix std (over folds):
# [[ 519.7101  527.9188]
#  [2010.1774 1997.363 ]]
# Running experiment: sextic_galois_lr_poly_normalized
# Data: sextic_galois_lr_poly_normalized, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8770, balanced_acc=0.5315
# Fold 2/5: acc=0.8650, balanced_acc=0.5009
# Fold 3/5: acc=0.8656, balanced_acc=0.5014
# Fold 4/5: acc=0.8631, balanced_acc=0.5010
# Fold 5/5: acc=0.8657, balanced_acc=0.5009
# Averaged classification report (mean ± std):
# accuracy: 0.8673 ± 0.0050
# balanced_acc: 0.5072 ± 0.0122
#
# per-class precision/recall/f1:
# 6T1: precision 0.9926 ± 0.0148, recall 0.0144 ± 0.0245, f1 0.0273 ± 0.0459
# 6T2: precision 0.8671 ± 0.0047, recall 0.9999 ± 0.0001, f1 0.9288 ± 0.0026
# Averaged confusion matrix (mean over folds):
# [[5.9600e+01 4.1696e+03]
#  [2.0000e+00 2.7202e+04]]
# Confusion matrix std (over folds):
# [[100.7107 159.5777]
#  [  4.      60.0853]]

# %%
# Distribution of polynomial coefficients
df_sextic_6T1 = df_sextic_galois.filter(pl.col("galois_label") == "6T1")
df_sextic_6T2 = df_sextic_galois.filter(pl.col("galois_label") == "6T2")
for i in range(6):
    print(f"c_{i}:")
    print(f"Mean: 6T1: {df_sextic_6T1[f'c_{i}'].mean()}, 6T2: {df_sextic_6T2[f'c_{i}'].mean()}")
    print(f"Mediean: 6T1: {df_sextic_6T1[f'c_{i}'].median()}, 6T2: {df_sextic_6T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 6T1: 4.397122621387055e+17, 6T2: 2217750846.4364367
# Mediean: 6T1: 148653.5, 6T2: 715682.0
# c_1:
# Mean: 6T1: -366062326578648.8, 6T2: -2416301.8775933306
# Mediean: 6T1: -2341.0, 6T2: 0.0
# c_2:
# Mean: 6T1: 76265344713.3534, 6T2: 195193.72077311022
# Mediean: 6T1: 133956.0, 6T2: 23128.5
# c_3:
# Mean: 6T1: 9103683.460465336, 6T2: 864.370065136522
# Mediean: 6T1: -2.0, 6T2: 0.0
# c_4:
# Mean: 6T1: -3102.2026387969354, 6T2: -137.8802840716943
# Mediean: 6T1: -77.0, 6T2: -50.0
# c_5:
# Mean: 6T1: -1.0549040007566444, 6T2: -0.7421887635823616
# Mediean: 6T1: -1.0, 6T2: 0.0

# %%
del df_sextic_galois, df_sextic_6T1, df_sextic_6T2

# %% [markdown]
# ### Decic
#
# - `10T1`: $C_{10}$
# - `10T2`: $D_5$

# %%
schema = {f"c_{i}": pl.Float64 for i in range(10)}
df_decic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_10_galois.csv", schema_overrides=schema)

# %%
df_stats(df_decic_galois, "galois_label")
# Out:
# Number of rows: 5476
# Number of columns: 10013
# Head: shape: (5, 10_013)
# ┌────────────────────┬──────┬──────────────┬──────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label              ┆ rank ┆ galois_label ┆ c_0  ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---                ┆ ---  ┆ ---          ┆ ---  ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str                ┆ i64  ┆ str          ┆ f64  ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞════════════════════╪══════╪══════════════╪══════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 10.0.229345007.1   ┆ 4    ┆ 10T2         ┆ 1.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.2357947691.1  ┆ 4    ┆ 10T1         ┆ 1.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.3077056399.1  ┆ 4    ┆ 10T2         ┆ 1.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.11592740743.1 ┆ 4    ┆ 10T2         ┆ 9.0  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 10.0.23863536599.2 ┆ 4    ┆ 10T2         ┆ 32.0 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# └────────────────────┴──────┴──────────────┴──────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬──────┬──────────┐
# │ galois_label ┆ len  ┆ percent  │
# │ ---          ┆ ---  ┆ ---      │
# │ str          ┆ u32  ┆ f64      │
# ╞══════════════╪══════╪══════════╡
# │ 10T1         ┆ 1854 ┆ 0.338568 │
# │ 10T2         ┆ 3622 ┆ 0.661432 │
# └──────────────┴──────┴──────────┘

# %%
run_experiments(df_decic_galois, "decic_galois", ["10T1", "10T2"], current_dir, [2, 5])
# Out:
# Running experiment: decic_galois_dt_zc_1000
# Data: decic_galois_dt_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9763, balanced_acc=0.9763
# Fold 2/5: acc=0.9753, balanced_acc=0.9708
# Fold 3/5: acc=0.9744, balanced_acc=0.9722
# Fold 4/5: acc=0.9699, balanced_acc=0.9687
# Fold 5/5: acc=0.9635, balanced_acc=0.9579
# Averaged classification report (mean ± std):
# accuracy: 0.9719 ± 0.0047
# balanced_acc: 0.9692 ± 0.0062
#
# per-class precision/recall/f1:
# 10T1: precision 0.9561 ± 0.0066, recall 0.9611 ± 0.0118, f1 0.9585 ± 0.0071
# 10T2: precision 0.9801 ± 0.0057, recall 0.9773 ± 0.0039, f1 0.9787 ± 0.0036
# Averaged confusion matrix (mean over folds):
# [[356.4  14.4]
#  [ 16.4 708. ]]
# Confusion matrix std (over folds):
# [[10.3846  4.2708]
#  [ 2.7276  9.859 ]]
# Running experiment: decic_galois_dt_zc_1000_sq_qu
# Data: decic_galois_dt_zc_1000_sq_qu, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9845, balanced_acc=0.9850
# Fold 2/5: acc=0.9863, balanced_acc=0.9840
# Fold 3/5: acc=0.9863, balanced_acc=0.9851
# Fold 4/5: acc=0.9890, balanced_acc=0.9884
# Fold 5/5: acc=0.9817, balanced_acc=0.9803
# Averaged classification report (mean ± std):
# accuracy: 0.9856 ± 0.0024
# balanced_acc: 0.9846 ± 0.0026
#
# per-class precision/recall/f1:
# 10T1: precision 0.9760 ± 0.0052, recall 0.9816 ± 0.0045, f1 0.9788 ± 0.0035
# 10T2: precision 0.9906 ± 0.0021, recall 0.9876 ± 0.0030, f1 0.9891 ± 0.0018
# Averaged confusion matrix (mean over folds):
# [[364.    6.8]
#  [  9.  715.4]]
# Confusion matrix std (over folds):
# [[9.0111 1.6   ]
#  [2.0976 9.1345]]
# Running experiment: decic_galois_dt_zc_1000_prime
# Data: decic_galois_dt_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8577, balanced_acc=0.8503
# Fold 2/5: acc=0.8603, balanced_acc=0.8521
# Fold 3/5: acc=0.8548, balanced_acc=0.8492
# Fold 4/5: acc=0.8475, balanced_acc=0.8390
# Fold 5/5: acc=0.8548, balanced_acc=0.8481
# Averaged classification report (mean ± std):
# accuracy: 0.8550 ± 0.0043
# balanced_acc: 0.8477 ± 0.0046
#
# per-class precision/recall/f1:
# 10T1: precision 0.7650 ± 0.0066, recall 0.8253 ± 0.0067, f1 0.7940 ± 0.0056
# 10T2: precision 0.9068 ± 0.0048, recall 0.8702 ± 0.0040, f1 0.8881 ± 0.0039
# Averaged confusion matrix (mean over folds):
# [[306.   64.8]
#  [ 94.  630.4]]
# Confusion matrix std (over folds):
# [[6.6332 3.0594]
#  [2.6077 8.4285]]
# Running experiment: decic_galois_dt_zc_1000_prime_power
# Data: decic_galois_dt_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9881, balanced_acc=0.9872
# Fold 2/5: acc=0.9790, balanced_acc=0.9757
# Fold 3/5: acc=0.9845, balanced_acc=0.9831
# Fold 4/5: acc=0.9763, balanced_acc=0.9729
# Fold 5/5: acc=0.9790, balanced_acc=0.9736
# Averaged classification report (mean ± std):
# accuracy: 0.9814 ± 0.0043
# balanced_acc: 0.9785 ± 0.0057
#
# per-class precision/recall/f1:
# 10T1: precision 0.9750 ± 0.0058, recall 0.9697 ± 0.0102, f1 0.9723 ± 0.0067
# 10T2: precision 0.9846 ± 0.0050, recall 0.9873 ± 0.0028, f1 0.9860 ± 0.0032
# Averaged confusion matrix (mean over folds):
# [[359.6  11.2]
#  [  9.2 715.2]]
# Confusion matrix std (over folds):
# [[10.1311  3.7094]
#  [ 2.0396  6.9685]]
# Running experiment: decic_galois_dt_poly
# Data: decic_galois_dt_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8595, balanced_acc=0.8486
# Fold 2/5: acc=0.8667, balanced_acc=0.8495
# Fold 3/5: acc=0.8758, balanced_acc=0.8594
# Fold 4/5: acc=0.8539, balanced_acc=0.8387
# Fold 5/5: acc=0.8795, balanced_acc=0.8701
# Averaged classification report (mean ± std):
# accuracy: 0.8671 ± 0.0096
# balanced_acc: 0.8532 ± 0.0107
#
# per-class precision/recall/f1:
# 10T1: precision 0.7996 ± 0.0158, recall 0.8106 ± 0.0169, f1 0.8050 ± 0.0140
# 10T2: precision 0.9024 ± 0.0083, recall 0.8959 ± 0.0098, f1 0.8991 ± 0.0077
# Averaged confusion matrix (mean over folds):
# [[300.6  70.2]
#  [ 75.4 649. ]]
# Confusion matrix std (over folds):
# [[ 9.7693  6.1774]
#  [ 6.8877 11.225 ]]
# Running experiment: decic_galois_lr_zc_1000
# Data: decic_galois_lr_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9307, balanced_acc=0.9290
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9443, balanced_acc=0.9427
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9342, balanced_acc=0.9288
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9370, balanced_acc=0.9334
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9443, balanced_acc=0.9414
# Averaged classification report (mean ± std):
# accuracy: 0.9381 ± 0.0054
# balanced_acc: 0.9351 ± 0.0060
#
# per-class precision/recall/f1:
# 10T1: precision 0.8953 ± 0.0077, recall 0.9257 ± 0.0091, f1 0.9102 ± 0.0065
# 10T2: precision 0.9612 ± 0.0055, recall 0.9445 ± 0.0054, f1 0.9528 ± 0.0046
# Averaged confusion matrix (mean over folds):
# [[343.2  27.6]
#  [ 40.2 684.2]]
# Confusion matrix std (over folds):
# [[ 5.6356  3.7736]
#  [ 3.6551 10.0479]]
# Mean: 0.06892176943222064
# Median: 0.0369980805033121
# Std: 0.0968391078243552
# Top 30: [1.0862672  0.83624003 0.81932498 0.66572297 0.38420941 0.38089253
#  0.38001722 0.37887146 0.37826276 0.37343987 0.36831621 0.36454572
#  0.33619907 0.32474856 0.32061053 0.31972684 0.3160482  0.31412698
#  0.30716943 0.29189947 0.28747077 0.28382057 0.27464776 0.27367155
#  0.25417338 0.2476959  0.24415448 0.24096371 0.23729665 0.23584751]
# Top 30 indices: [ 48  31  24 287 544 276 971 315 520  82 862  99 408 820 910 979 760 808
#  234 242 398 882 280 558 826 763 684 906 798 187]
# Bottom 30: [-0.60736884 -0.59110018 -0.53461274 -0.47886167 -0.44752113 -0.44041064
#  -0.39424165 -0.37266404 -0.32584453 -0.31923735 -0.28266696 -0.27943393
#  -0.27263316 -0.27122374 -0.26733895 -0.26561382 -0.25089205 -0.24035725
#  -0.23459612 -0.21179412 -0.20996483 -0.20799533 -0.20563443 -0.20485343
#  -0.20483874 -0.19778153 -0.19704775 -0.18594508 -0.18354262 -0.17453541]
# Bottom 30 indices: [ 94 124  30  10  16  18 342 127 647  22 488 672  66  28 630  26 431  12
#  400 304 410 363 462 843 838 294 175 718 394 150]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF F,G EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Mean: 0.2084487425848745
# Median: 0.11567156273182187
# Std: 0.25168426719082115
# Running experiment: decic_galois_lr_zc_1000_normalized
# Data: decic_galois_lr_zc_1000_normalized, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9507, balanced_acc=0.9469
# Fold 2/5: acc=0.9452, balanced_acc=0.9383
# Fold 3/5: acc=0.9388, balanced_acc=0.9336
# Fold 4/5: acc=0.9571, balanced_acc=0.9532
# Fold 5/5: acc=0.9434, balanced_acc=0.9381
# Averaged classification report (mean ± std):
# accuracy: 0.9470 ± 0.0063
# balanced_acc: 0.9420 ± 0.0070
#
# per-class precision/recall/f1:
# 10T1: precision 0.9177 ± 0.0101, recall 0.9265 ± 0.0094, f1 0.9221 ± 0.0097
# 10T2: precision 0.9623 ± 0.0044, recall 0.9575 ± 0.0051, f1 0.9599 ± 0.0047
# Averaged confusion matrix (mean over folds):
# [[343.6  27.2]
#  [ 30.8 693.6]]
# Confusion matrix std (over folds):
# [[9.625  3.2496]
#  [3.7094 8.2849]]
# Mean: 0.21819537486861593
# Median: 0.12426916600890531
# Std: 0.3350707643431466
# Top 30: [3.88192149 3.44419877 2.35007256 2.33730967 2.32997235 1.74965328
#  1.65246811 1.64503441 1.38383356 1.321875   1.28695451 1.28560721
#  1.21525911 1.13042768 1.10028832 1.08717184 1.0802186  1.05971005
#  1.03985056 1.03099899 0.9891485  0.96457069 0.95445209 0.94119909
#  0.92813732 0.9005737  0.80524715 0.76425232 0.76076001 0.74445406]
# Top 30 indices: [ 24  48 960 120   8 840 528 288 168 360 724 315   3 170 440 474 195 962
#  224 651  35 483  99 368  98 283 216 530 174 332]
# Bottom 30: [-2.68470118 -2.06292845 -2.05673071 -1.64824192 -1.59474582 -1.54043861
#  -1.52020625 -1.31962225 -1.26791528 -1.22845574 -1.07156836 -1.01953284
#  -0.98996125 -0.8365842  -0.74641431 -0.70570135 -0.68160917 -0.6810523
#  -0.67813308 -0.66692663 -0.66360385 -0.60833037 -0.59824534 -0.57717018
#  -0.57570586 -0.5715486  -0.54572008 -0.5438462  -0.54247905 -0.52525167]
# Bottom 30 indices: [342  30  10   4 124  16  28  22  12  18 624 843  94  90 488  64 547   6
#   34 242 939  76 144 188 361 128  26 728 746 553]
# Mean: 0.9931322436425757
# Median: 0.9544520906563209
# Std: 0.9521001919657427
# Running experiment: decic_galois_lr_zc_1000_sq_qu
# Data: decic_galois_lr_zc_1000_sq_qu, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9489, balanced_acc=0.9467
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9534, balanced_acc=0.9488
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9580, balanced_acc=0.9514
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9233, balanced_acc=0.9146
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9397, balanced_acc=0.9340
# Averaged classification report (mean ± std):
# accuracy: 0.9447 ± 0.0123
# balanced_acc: 0.9391 ± 0.0136
#
# per-class precision/recall/f1:
# 10T1: precision 0.9155 ± 0.0191, recall 0.9218 ± 0.0189, f1 0.9186 ± 0.0178
# 10T2: precision 0.9598 ± 0.0099, recall 0.9564 ± 0.0102, f1 0.9581 ± 0.0094
# Averaged confusion matrix (mean over folds):
# [[341.8  29. ]
#  [ 31.6 692.8]]
# Confusion matrix std (over folds):
# [[ 9.6623  7.1274]
#  [ 7.3376 11.6   ]]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Running experiment: decic_galois_lr_zc_1000_prime
# Data: decic_galois_lr_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8686, balanced_acc=0.8395
# Fold 2/5: acc=0.8566, balanced_acc=0.8217
# Fold 3/5: acc=0.8575, balanced_acc=0.8185
# Fold 4/5: acc=0.8566, balanced_acc=0.8284
# Fold 5/5: acc=0.8548, balanced_acc=0.8186
# Averaged classification report (mean ± std):
# accuracy: 0.8588 ± 0.0050
# balanced_acc: 0.8253 ± 0.0080
#
# per-class precision/recall/f1:
# 10T1: precision 0.8391 ± 0.0183, recall 0.7216 ± 0.0190, f1 0.7756 ± 0.0116
# 10T2: precision 0.8671 ± 0.0072, recall 0.9291 ± 0.0089, f1 0.8970 ± 0.0031
# Averaged confusion matrix (mean over folds):
# [[267.6 103.2]
#  [ 51.4 673. ]]
# Confusion matrix std (over folds):
# [[10.0916  6.9971]
#  [ 6.7409  6.8993]]
# Running experiment: decic_galois_lr_zc_1000_prime_power
# Data: decic_galois_lr_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9662, balanced_acc=0.9655
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9708, balanced_acc=0.9660
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9589, balanced_acc=0.9514
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9626, balanced_acc=0.9612
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9699, balanced_acc=0.9628
# Averaged classification report (mean ± std):
# accuracy: 0.9657 ± 0.0045
# balanced_acc: 0.9614 ± 0.0053
#
# per-class precision/recall/f1:
# 10T1: precision 0.9506 ± 0.0123, recall 0.9482 ± 0.0126, f1 0.9493 ± 0.0061
# 10T2: precision 0.9736 ± 0.0063, recall 0.9746 ± 0.0072, f1 0.9740 ± 0.0035
# Averaged confusion matrix (mean over folds):
# [[351.6  19.2]
#  [ 18.4 706. ]]
# Confusion matrix std (over folds):
# [[ 9.2     4.7074]
#  [ 5.1225 11.2428]]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Running experiment: decic_galois_lr_poly
# Data: decic_galois_lr_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.5411, balanced_acc=0.6234
# Fold 2/5: acc=0.4648, balanced_acc=0.5962
# Fold 3/5: acc=0.4703, balanced_acc=0.5868
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.4018, balanced_acc=0.4835
# Fold 5/5: acc=0.4347, balanced_acc=0.5561
# Averaged classification report (mean ± std):
# accuracy: 0.4625 ± 0.0462
# balanced_acc: 0.5692 ± 0.0479
#
# per-class precision/recall/f1:
# 10T1: precision 0.3771 ± 0.0299, recall 0.8982 ± 0.0835, f1 0.5305 ± 0.0396
# 10T2: precision 0.8346 ± 0.1091, recall 0.2402 ± 0.0597, f1 0.3684 ± 0.0705
# Averaged confusion matrix (mean over folds):
# [[332.8  38. ]
#  [550.6 173.8]]
# Confusion matrix std (over folds):
# [[28.9786 31.2538]
#  [46.0156 41.9829]]
# Running experiment: decic_galois_lr_poly_normalized
# Data: decic_galois_lr_poly_normalized, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.6533, balanced_acc=0.5000
# Fold 2/5: acc=0.6767, balanced_acc=0.5028
# Fold 3/5: acc=0.6584, balanced_acc=0.5000
# Fold 4/5: acc=0.6594, balanced_acc=0.5000
# Fold 5/5: acc=0.6612, balanced_acc=0.5000
# Averaged classification report (mean ± std):
# accuracy: 0.6618 ± 0.0079
# balanced_acc: 0.5006 ± 0.0011
#
# per-class precision/recall/f1:
# 10T1: precision 0.2000 ± 0.4000, recall 0.0011 ± 0.0022, f1 0.0022 ± 0.0045
# 10T2: precision 0.6617 ± 0.0077, recall 1.0000 ± 0.0000, f1 0.7964 ± 0.0055
# Averaged confusion matrix (mean over folds):
# [[4.000e-01 3.704e+02]
#  [0.000e+00 7.244e+02]]
# Confusion matrix std (over folds):
# [[0.8    8.7316]
#  [0.     7.7614]]

# %%
# Distribution of polynomial coefficients
df_decic_10T1 = df_decic_galois.filter(pl.col("galois_label") == "10T1")
df_decic_10T2 = df_decic_galois.filter(pl.col("galois_label") == "10T2")
for i in range(6):
    print(f"c_{i}:")
    print(f"Mean: 10T1: {df_decic_10T1[f'c_{i}'].mean()}, 10T2: {df_decic_10T2[f'c_{i}'].mean()}")
    print(f"Mediean: 10T1: {df_decic_10T1[f'c_{i}'].median()}, 10T2: {df_decic_10T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 10T1: 3.2751681160246415e+19, 10T2: 8067610.266703479
# Mediean: 10T1: 183633.0, 10T2: 812144.0
# c_1:
# Mean: 10T1: -1.0067062842059324e+18, 10T2: -202378.10049696302
# Mediean: 10T1: -495351.0, 10T2: 0.0
# c_2:
# Mean: 10T1: 7746535577696627.0, 10T2: 769342.605466593
# Mediean: 10T1: 14831547.0, 10T2: 129930.5
# c_3:
# Mean: 10T1: 36695895596564.53, 10T2: -6039.120375483159
# Mediean: 10T1: 0.0, 10T2: 0.0
# c_4:
# Mean: 10T1: -569812488131.5636, 10T2: 28733.506902263944
# Mediean: 10T1: 778.5, 10T2: 13503.5
# c_5:
# Mean: 10T1: -270990336.93419635, 10T2: -1047.7020982882386
# Mediean: 10T1: -8424.0, 10T2: 0.0

# %%
del df_decic_galois, df_decic_10T1, df_decic_10T2
