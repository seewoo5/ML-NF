# %% [markdown]
# ### Classifying Galois group of Quartic and Nonic extensions

# %%
from utils import *

current_dir = globals()['_dh'][0]

# %% [markdown]
# ### Quartic
#
# - `4T1`: $C_4$
# - `4T2`: $C_2^2$

# %%
df_quartic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_4_galois.csv")

# %%
df_stats(df_quartic_galois, "galois_label")
# Out:
# Number of rows: 182860
# Number of columns: 10007
# Head: shape: (5, 10_007)
# ┌───────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label     ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---       ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str       ┆ i64  ┆ str          ┆ i64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═══════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 4.0.125.1 ┆ 1    ┆ 4T1          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 1       │
# │ 4.0.144.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 16      ┆ 0       ┆ 0       ┆ 3       │
# │ 4.0.225.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 4.0.256.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 3       │
# │ 4.0.400.1 ┆ 1    ┆ 4T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 5       │
# └───────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬────────┬──────────┐
# │ galois_label ┆ len    ┆ percent  │
# │ ---          ┆ ---    ┆ ---      │
# │ str          ┆ u32    ┆ f64      │
# ╞══════════════╪════════╪══════════╡
# │ 4T1          ┆ 21873  ┆ 0.119616 │
# │ 4T2          ┆ 160987 ┆ 0.880384 │
# └──────────────┴────────┴──────────┘

# %%
run_experiments(df_quartic_galois, "quartic_galois", ["4T1", "4T2"], current_dir, [2])
# Out:
# Running experiment: quartic_galois_dt_zc_1000
# Data: quartic_galois_dt_zc_1000, a
# Train: (146288, 1000)
# Test (galois_label): (36572, 1000)
#               precision    recall  f1-score   support
#
#          4T1     1.0000    0.9991    0.9995      4390
#          4T2     0.9999    1.0000    0.9999     32182
#
#     accuracy                         0.9999     36572
#    macro avg     0.9999    0.9995    0.9997     36572
# weighted avg     0.9999    0.9999    0.9999     36572
#
# balanced ACC: 0.9995444191343963
# Confusion matrix
# Running experiment: quartic_galois_dt_zc_1000_sq
# Data: quartic_galois_dt_zc_1000_sq, a
# Train: (146288, 30)
# Test (galois_label): (36572, 30)
#               precision    recall  f1-score   support
#
#          4T1     0.9995    0.9991    0.9993      4390
#          4T2     0.9999    0.9999    0.9999     32182
#
#     accuracy                         0.9998     36572
#    macro avg     0.9997    0.9995    0.9996     36572
# weighted avg     0.9998    0.9998    0.9998     36572
#
# balanced ACC: 0.9995133458636238
# Confusion matrix
# Running experiment: quartic_galois_dt_zc_1000_prime
# Data: quartic_galois_dt_zc_1000_prime, a_p
# Train: (146288, 168)
# Test (galois_label): (36572, 168)
#               precision    recall  f1-score   support
#
#          4T1     0.6266    0.6385    0.6325      4390
#          4T2     0.9506    0.9481    0.9493     32182
#
#     accuracy                         0.9109     36572
#    macro avg     0.7886    0.7933    0.7909     36572
# weighted avg     0.9117    0.9109    0.9113     36572
#
# balanced ACC: 0.7933021104767319
# Confusion matrix
# Running experiment: quartic_galois_dt_zc_1000_prime_power
# Data: quartic_galois_dt_zc_1000_prime_power, a_pp
# Train: (146288, 193)
# Test (galois_label): (36572, 193)
#               precision    recall  f1-score   support
#
#          4T1     1.0000    0.9991    0.9995      4390
#          4T2     0.9999    1.0000    0.9999     32182
#
#     accuracy                         0.9999     36572
#    macro avg     0.9999    0.9995    0.9997     36572
# weighted avg     0.9999    0.9999    0.9999     36572
#
# balanced ACC: 0.9995444191343963
# Confusion matrix
# Running experiment: quartic_galois_dt_poly
# Data: quartic_galois_dt_poly, c
# Train: (146288, 4)
# Test (galois_label): (36572, 4)
#               precision    recall  f1-score   support
#
#          4T1     0.7917    0.7740    0.7828      4390
#          4T2     0.9693    0.9722    0.9707     32182
#
#     accuracy                         0.9484     36572
#    macro avg     0.8805    0.8731    0.8768     36572
# weighted avg     0.9480    0.9484    0.9482     36572
#
# balanced ACC: 0.873126193294997
# Confusion matrix
# Running experiment: quartic_galois_lr_zc_1000
# Data: quartic_galois_lr_zc_1000, a
# Train: (146288, 1000)
# Test (galois_label): (36572, 1000)
#               precision    recall  f1-score   support
#
#          4T1     0.9887    0.9804    0.9846      4390
#          4T2     0.9973    0.9985    0.9979     32182
#
#     accuracy                         0.9963     36572
#    macro avg     0.9930    0.9894    0.9912     36572
# weighted avg     0.9963    0.9963    0.9963     36572
#
# balanced ACC: 0.9894437162555958
# Confusion matrix
# Mean: 0.18934697177850668
# Median: 0.04272632246458127
# Std: 0.6009203372301775
# Top 30: [6.81976392 5.83791877 4.47119693 3.158068   2.92968564 2.27703781
#  1.96443445 1.86444132 1.71120886 1.69121775 1.62335782 1.56060569
#  1.17030818 1.1143298  1.02982554 1.02295968 1.02276017 0.90172163
#  0.89276059 0.88358051 0.87926149 0.78857672 0.7441996  0.67728532
#  0.62209234 0.61202938 0.5991462  0.59470527 0.56462822 0.56024571]
# Top 30 indices: [ 24 124  35  48  99 960 840 528  49   8 728 360 288 319  71 134 168 296
#  971  63  62  74  98  67 483  39 101 188 799 195]
# Bottom 30: [-6.10805048 -5.39949658 -5.03118811 -4.61201652 -4.11050947 -3.97924613
#  -3.51881451 -3.39970316 -2.96366401 -2.78696736 -2.59075151 -2.2100846
#  -2.01412546 -1.9602877  -1.94637471 -1.75869825 -1.61573062 -1.35730401
#  -1.22022598 -1.03954281 -0.94819547 -0.93293442 -0.90961852 -0.90178203
#  -0.87925839 -0.78423096 -0.74702885 -0.7417892  -0.70291112 -0.68363836]
# Bottom 30 indices: [  4   0  30 624  28  22  80  18  16  19 323   1  12   3 342  15  14 199
#   37 399  10   7  41  29  65 242  33  32 639  79]
# Mean: 1.6648616839888273
# Median: 1.3654569315864342
# Std: 1.5838160829773744
# Running experiment: quartic_galois_lr_zc_1000_sq
# Data: quartic_galois_lr_zc_1000_sq, a
# Train: (146288, 30)
# Test (galois_label): (36572, 30)
#               precision    recall  f1-score   support
#
#          4T1     0.9880    0.8426    0.9095      4390
#          4T2     0.9790    0.9986    0.9887     32182
#
#     accuracy                         0.9799     36572
#    macro avg     0.9835    0.9206    0.9491     36572
# weighted avg     0.9800    0.9799    0.9792     36572
#
# balanced ACC: 0.9205992568745895
# Confusion matrix
# Running experiment: quartic_galois_lr_zc_1000_prime
# Data: quartic_galois_lr_zc_1000_prime, a_p
# Train: (146288, 168)
# Test (galois_label): (36572, 168)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#          4T1     0.0000    0.0000    0.0000      4390
#          4T2     0.8800    1.0000    0.9361     32182
#
#     accuracy                         0.8800     36572
#    macro avg     0.4400    0.5000    0.4681     36572
# weighted avg     0.7743    0.8800    0.8238     36572
#
# balanced ACC: 0.5
# Confusion matrix
# Running experiment: quartic_galois_lr_zc_1000_prime_power
# Data: quartic_galois_lr_zc_1000_prime_power, a_pp
# Train: (146288, 193)
# Test (galois_label): (36572, 193)
#               precision    recall  f1-score   support
#
#          4T1     0.9935    0.9784    0.9859      4390
#          4T2     0.9971    0.9991    0.9981     32182
#
#     accuracy                         0.9966     36572
#    macro avg     0.9953    0.9887    0.9920     36572
# weighted avg     0.9966    0.9966    0.9966     36572
#
# balanced ACC: 0.9887449286510988
# Confusion matrix
# Running experiment: quartic_galois_lr_poly
# Data: quartic_galois_lr_poly, c
# Train: (146288, 4)
# Test (galois_label): (36572, 4)
#               precision    recall  f1-score   support
#
#          4T1     0.1037    0.7139    0.1810      4390
#          4T2     0.8019    0.1579    0.2639     32182
#
#     accuracy                         0.2247     36572
#    macro avg     0.4528    0.4359    0.2225     36572
# weighted avg     0.7181    0.2247    0.2540     36572
#
# balanced ACC: 0.4359203258687173
# Confusion matrix
# Running experiment: quartic_galois_lr_poly_normalized
# Data: quartic_galois_lr_poly_normalized, c
# Train: (146288, 4)
# Test (galois_label): (36572, 4)
#               precision    recall  f1-score   support
#
#          4T1     1.0000    0.0007    0.0014      4390
#          4T2     0.8800    1.0000    0.9362     32182
#
#     accuracy                         0.8800     36572
#    macro avg     0.9400    0.5003    0.4688     36572
# weighted avg     0.8944    0.8800    0.8240     36572
#
# balanced ACC: 0.5003416856492028
# Confusion matrix

# %%
# Distribution of polynomial coefficients
df_quartic_4T1 = df_quartic_galois.filter(pl.col("galois_label") == "4T1")
df_quartic_4T2 = df_quartic_galois.filter(pl.col("galois_label") == "4T2")
for i in range(4):
    print(f"c_{i}:")
    print(f"Mean: 4T1: {df_quartic_4T1[f'c_{i}'].mean()}, 4T2: {df_quartic_4T2[f'c_{i}'].mean()}")
    print(f"Mediean: 4T1: {df_quartic_4T1[f'c_{i}'].median()}, 4T2: {df_quartic_4T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 4T1: 102882526443.64673, 4T2: 62525821.141129404
# Mediean: 4T1: 2094672.0, 4T2: 96727.0
# c_1:
# Mean: 4T1: -11064534.074703973, 4T2: 77.18341232521881
# Mediean: 4T1: 0.0, 4T2: 0.0
# c_2:
# Mean: 4T1: -40876.83107026928, 4T2: -464.29426599663327
# Mediean: 4T1: -189.0, 4T2: -52.0
# c_3:
# Mean: 4T1: -0.5991862113107485, 4T2: -0.528899849056135
# Mediean: 4T1: -1.0, 4T2: 0.0

# %%
del df_quartic_galois, df_quartic_4T1, df_quartic_4T2

# %% [markdown]
# ### Nonic
#
# - `9T1`: $C_9$
# - `9T2`: $C_3^2$

# %%
df_nonic_galois = pl.read_csv(f"{current_dir}/data_nf/nf_9_galois.csv")

# %%
df_stats(df_nonic_galois, "galois_label")
# Out:
# Number of rows: 1266
# Number of columns: 10012
# Head: shape: (5, 10_012)
# ┌─────────────────────┬──────┬──────────────┬─────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ label               ┆ rank ┆ galois_label ┆ c_0 ┆ … ┆ a_09997 ┆ a_09998 ┆ a_09999 ┆ a_10000 │
# │ ---                 ┆ ---  ┆ ---          ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str                 ┆ i64  ┆ str          ┆ i64 ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞═════════════════════╪══════╪══════════════╪═════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 9.9.16983563041.1   ┆ 8    ┆ 9T1          ┆ -1  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.31381059609.1   ┆ 8    ┆ 9T1          ┆ -1  ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.62523502209.1   ┆ 8    ┆ 9T2          ┆ 1   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.567869252041.1  ┆ 8    ┆ 9T2          ┆ 8   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │ 9.9.2565164201769.1 ┆ 8    ┆ 9T2          ┆ -53 ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# └─────────────────────┴──────┴──────────────┴─────┴───┴─────────┴─────────┴─────────┴─────────┘
# Label: galois_label
# Label value counts: shape: (2, 3)
# ┌──────────────┬─────┬──────────┐
# │ galois_label ┆ len ┆ percent  │
# │ ---          ┆ --- ┆ ---      │
# │ str          ┆ u32 ┆ f64      │
# ╞══════════════╪═════╪══════════╡
# │ 9T1          ┆ 284 ┆ 0.224329 │
# │ 9T2          ┆ 982 ┆ 0.775671 │
# └──────────────┴─────┴──────────┘

# %%
run_experiments(df_nonic_galois, "nonic_galois", ["9T1", "9T2"], current_dir, [3])
# Out:
# Running experiment: nonic_galois_dt_zc_1000
# Data: nonic_galois_dt_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=1.0000, balanced_acc=1.0000
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 1.0000 ± 0.0000
#
# per-class precision/recall/f1:
# 9T1: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# 9T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[ 56.8   0. ]
#  [  0.  196.4]]
# Confusion matrix std (over folds):
# [[8.1339 0.    ]
#  [0.     8.2849]]
# Running experiment: nonic_galois_dt_zc_1000_cb
# Data: nonic_galois_dt_zc_1000_cb, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=1.0000, balanced_acc=1.0000
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 1.0000 ± 0.0000
#
# per-class precision/recall/f1:
# 9T1: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# 9T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[ 56.8   0. ]
#  [  0.  196.4]]
# Confusion matrix std (over folds):
# [[8.1339 0.    ]
#  [0.     8.2849]]
# Running experiment: nonic_galois_dt_zc_1000_prime
# Data: nonic_galois_dt_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9291, balanced_acc=0.8823
# Fold 2/5: acc=0.9170, balanced_acc=0.8553
# Fold 3/5: acc=0.9170, balanced_acc=0.8987
# Fold 4/5: acc=0.9289, balanced_acc=0.9023
# Fold 5/5: acc=0.9328, balanced_acc=0.8913
# Averaged classification report (mean ± std):
# accuracy: 0.9250 ± 0.0066
# balanced_acc: 0.8860 ± 0.0168
#
# per-class precision/recall/f1:
# 9T1: precision 0.8427 ± 0.0378, recall 0.8157 ± 0.0421, f1 0.8276 ± 0.0216
# 9T2: precision 0.9475 ± 0.0125, recall 0.9562 ± 0.0123, f1 0.9517 ± 0.0051
# Averaged confusion matrix (mean over folds):
# [[ 46.4  10.4]
#  [  8.6 187.8]]
# Confusion matrix std (over folds):
# [[7.6315 2.5768]
#  [2.4166 8.2801]]
# Running experiment: nonic_galois_dt_zc_1000_prime_power
# Data: nonic_galois_dt_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=1.0000, balanced_acc=1.0000
# Fold 2/5: acc=1.0000, balanced_acc=1.0000
# Fold 3/5: acc=1.0000, balanced_acc=1.0000
# Fold 4/5: acc=1.0000, balanced_acc=1.0000
# Fold 5/5: acc=1.0000, balanced_acc=1.0000
# Averaged classification report (mean ± std):
# accuracy: 1.0000 ± 0.0000
# balanced_acc: 1.0000 ± 0.0000
#
# per-class precision/recall/f1:
# 9T1: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# 9T2: precision 1.0000 ± 0.0000, recall 1.0000 ± 0.0000, f1 1.0000 ± 0.0000
# Averaged confusion matrix (mean over folds):
# [[ 56.8   0. ]
#  [  0.  196.4]]
# Confusion matrix std (over folds):
# [[8.1339 0.    ]
#  [0.     8.2849]]
# Running experiment: nonic_galois_dt_poly
# Data: nonic_galois_dt_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9528, balanced_acc=0.9484
# Fold 2/5: acc=0.8972, balanced_acc=0.8607
# Fold 3/5: acc=0.9289, balanced_acc=0.9064
# Fold 4/5: acc=0.9605, balanced_acc=0.9374
# Fold 5/5: acc=0.9684, balanced_acc=0.9553
# Averaged classification report (mean ± std):
# accuracy: 0.9415 ± 0.0258
# balanced_acc: 0.9216 ± 0.0348
#
# per-class precision/recall/f1:
# 9T1: precision 0.8619 ± 0.0674, recall 0.8838 ± 0.0538, f1 0.8718 ± 0.0529
# 9T2: precision 0.9648 ± 0.0181, recall 0.9594 ± 0.0212, f1 0.9620 ± 0.0170
# Averaged confusion matrix (mean over folds):
# [[ 50.    6.8]
#  [  8.  188.4]]
# Confusion matrix std (over folds):
# [[6.5422 3.4293]
#  [4.1473 8.309 ]]
# Running experiment: nonic_galois_lr_zc_1000
# Data: nonic_galois_lr_zc_1000, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9724, balanced_acc=0.9314
# Fold 2/5: acc=0.9763, balanced_acc=0.9483
# Fold 3/5: acc=0.9842, balanced_acc=0.9720
# Fold 4/5: acc=0.9565, balanced_acc=0.9258
# Fold 5/5: acc=0.9684, balanced_acc=0.9553
# Averaged classification report (mean ± std):
# accuracy: 0.9716 ± 0.0092
# balanced_acc: 0.9466 ± 0.0167
#
# per-class precision/recall/f1:
# 9T1: precision 0.9724 ± 0.0390, recall 0.9001 ± 0.0370, f1 0.9336 ± 0.0193
# 9T2: precision 0.9710 ± 0.0138, recall 0.9930 ± 0.0089, f1 0.9818 ± 0.0063
# Averaged confusion matrix (mean over folds):
# [[ 51.    5.8]
#  [  1.4 195. ]]
# Confusion matrix std (over folds):
# [[6.6332 2.6382]
#  [1.8547 7.5631]]
# Mean: 0.02153243406328469
# Median: 0.002129267299576248
# Std: 0.047178651606309345
# Top 30: [0.65618972 0.62181152 0.20253327 0.16890661 0.15889365 0.15857956
#  0.12738834 0.11457897 0.11035282 0.10821458 0.10714843 0.09570154
#  0.09287334 0.08858555 0.08352941 0.08037118 0.07683301 0.07623645
#  0.07354628 0.07188982 0.07077285 0.07069099 0.06763826 0.06741345
#  0.06568557 0.06143896 0.06111705 0.06111231 0.05709203 0.05678985]
# Top 30 indices: [215 999  63 512 124 247  26   7 998 471 135 183 231 350 583 447 567 620
#  295 882 871 663 423 232 162 855 880 836 658 700]
# Bottom 30: [-0.59224018 -0.26090089 -0.16559586 -0.163905   -0.16237059 -0.16177429
#  -0.15613243 -0.15580672 -0.14785722 -0.14781453 -0.1455804  -0.13790685
#  -0.13775439 -0.1323977  -0.13145571 -0.12819284 -0.1256668  -0.12219982
#  -0.12193167 -0.11997375 -0.1196636  -0.11934305 -0.11827367 -0.11736722
#  -0.11730777 -0.11700982 -0.11503416 -0.11351213 -0.11286199 -0.10923214]
# Bottom 30 indices: [624 982 198 940 808 460 358 199 568 366 750 228 240 676 612 255 806 242
#  928 618 752 100 990 630 292 822 316 190 946 136]
# Mean: 0.2217515646094568
# Median: 0.12738833760162863
# Std: 0.22970084301572583
# Running experiment: nonic_galois_lr_zc_1000_cb
# Data: nonic_galois_lr_zc_1000_cb, a
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.9606, balanced_acc=0.9020
# Fold 2/5: acc=0.9565, balanced_acc=0.9112
# Fold 3/5: acc=0.9605, balanced_acc=0.9153
# Fold 4/5: acc=0.9526, balanced_acc=0.9143
# Fold 5/5: acc=0.9684, balanced_acc=0.9130
# Averaged classification report (mean ± std):
# accuracy: 0.9597 ± 0.0052
# balanced_acc: 0.9112 ± 0.0048
#
# per-class precision/recall/f1:
# 9T1: precision 0.9959 ± 0.0082, recall 0.8233 ± 0.0098, f1 0.9014 ± 0.0062
# 9T2: precision 0.9513 ± 0.0077, recall 0.9990 ± 0.0021, f1 0.9745 ± 0.0042
# Averaged confusion matrix (mean over folds):
# [[ 46.8  10. ]
#  [  0.2 196.2]]
# Confusion matrix std (over folds):
# [[6.9685 1.2649]
#  [0.4    8.3283]]
# Running experiment: nonic_galois_lr_zc_1000_prime
# Data: nonic_galois_lr_zc_1000_prime, a_p
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.7165, balanced_acc=0.5437
# Fold 2/5: acc=0.7233, balanced_acc=0.5480
# Fold 3/5: acc=0.7470, balanced_acc=0.5874
# Fold 4/5: acc=0.7312, balanced_acc=0.5981
# Fold 5/5: acc=0.7668, balanced_acc=0.5616
# Averaged classification report (mean ± std):
# accuracy: 0.7370 ± 0.0180
# balanced_acc: 0.5677 ± 0.0215
#
# per-class precision/recall/f1:
# 9T1: precision 0.3788 ± 0.0901, recall 0.2613 ± 0.0287, f1 0.3073 ± 0.0479
# 9T2: precision 0.8041 ± 0.0234, recall 0.8742 ± 0.0223, f1 0.8373 ± 0.0135
# Averaged confusion matrix (mean over folds):
# [[ 15.   41.8]
#  [ 24.8 171.6]]
# Confusion matrix std (over folds):
# [[3.5777 4.9558]
#  [5.0359 6.2801]]
# Running experiment: nonic_galois_lr_zc_1000_prime_power
# Data: nonic_galois_lr_zc_1000_prime_power, a_pp
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 1/5: acc=0.9764, balanced_acc=0.9485
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 2/5: acc=0.9565, balanced_acc=0.9173
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 3/5: acc=0.9605, balanced_acc=0.9388
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 4/5: acc=0.9605, balanced_acc=0.9330
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fold 5/5: acc=0.9723, balanced_acc=0.9408
# Averaged classification report (mean ± std):
# accuracy: 0.9652 ± 0.0077
# balanced_acc: 0.9357 ± 0.0105
#
# per-class precision/recall/f1:
# 9T1: precision 0.9613 ± 0.0193, recall 0.8816 ± 0.0212, f1 0.9194 ± 0.0130
# 9T2: precision 0.9659 ± 0.0100, recall 0.9898 ± 0.0056, f1 0.9777 ± 0.0055
# Averaged confusion matrix (mean over folds):
# [[ 50.    6.8]
#  [  2.  194.4]]
# Confusion matrix std (over folds):
# [[6.7528 1.833 ]
#  [1.0954 8.309 ]]
# /Users/seewoolee/Documents/development/ml-nf/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Running experiment: nonic_galois_lr_poly
# Data: nonic_galois_lr_poly, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8543, balanced_acc=0.6740
# Fold 2/5: acc=0.8498, balanced_acc=0.6845
# Fold 3/5: acc=0.8340, balanced_acc=0.6912
# Fold 4/5: acc=0.7984, balanced_acc=0.6534
# Fold 5/5: acc=0.8893, balanced_acc=0.7295
# Averaged classification report (mean ± std):
# accuracy: 0.8452 ± 0.0295
# balanced_acc: 0.6865 ± 0.0250
#
# per-class precision/recall/f1:
# 9T1: precision 0.8328 ± 0.0546, recall 0.3965 ± 0.0508, f1 0.5344 ± 0.0455
# 9T2: precision 0.8471 ± 0.0331, recall 0.9765 ± 0.0101, f1 0.9069 ± 0.0198
# Averaged confusion matrix (mean over folds):
# [[ 22.2  34.6]
#  [  4.6 191.8]]
# Confusion matrix std (over folds):
# [[1.9391 7.4189]
#  [1.9596 8.5182]]
# Running experiment: nonic_galois_lr_poly_normalized
# Data: nonic_galois_lr_poly_normalized, c
# Cross validation: KFold(n_splits=5, shuffle=True, random_state=42)
# Fold 1/5: acc=0.8780, balanced_acc=0.7034
# Fold 2/5: acc=0.8577, balanced_acc=0.6897
# Fold 3/5: acc=0.8419, balanced_acc=0.6728
# Fold 4/5: acc=0.7984, balanced_acc=0.6357
# Fold 5/5: acc=0.8972, balanced_acc=0.7343
# Averaged classification report (mean ± std):
# accuracy: 0.8546 ± 0.0337
# balanced_acc: 0.6872 ± 0.0327
#
# per-class precision/recall/f1:
# 9T1: precision 0.9569 ± 0.0381, recall 0.3793 ± 0.0679, f1 0.5386 ± 0.0674
# 9T2: precision 0.8454 ± 0.0381, recall 0.9950 ± 0.0045, f1 0.9136 ± 0.0215
# Averaged confusion matrix (mean over folds):
# [[ 21.   35.8]
#  [  1.  195.4]]
# Confusion matrix std (over folds):
# [[1.0954 9.0421]
#  [0.8944 7.7614]]

# %%
# Distribution of polynomial coefficients
df_nonic_9T1 = df_nonic_galois.filter(pl.col("galois_label") == "9T1")
df_nonic_9T2 = df_nonic_galois.filter(pl.col("galois_label") == "9T2")
for i in range(9):
    print(f"c_{i}:")
    print(f"Mean: 9T1: {df_nonic_9T1[f'c_{i}'].mean()}, 9T2: {df_nonic_9T2[f'c_{i}'].mean()}")
    print(f"Mediean: 9T1: {df_nonic_9T1[f'c_{i}'].median()}, 9T2: {df_nonic_9T2[f'c_{i}'].median()}")
# Out:
# c_0:
# Mean: 9T1: -447118227.8169014, 9T2: -1466653860.4256618
# Mediean: 9T1: -198468.5, 9T2: -54243.5
# c_1:
# Mean: 9T1: 811066533.2464789, 9T2: -843469234.919552
# Mediean: 9T1: 8149986.0, 9T2: -1031126.0
# c_2:
# Mean: 9T1: -49031122.795774646, 9T2: -120032764.83910386
# Mediean: 9T1: -50715.0, 9T2: -1921468.0
# c_3:
# Mean: 9T1: -24216259.570422534, 9T2: -9416349.268839104
# Mediean: 9T1: -4621031.0, 9T2: -912550.0
# c_4:
# Mean: 9T1: 442437.2042253521, 9T2: 615257.00101833
# Mediean: 9T1: 12357.5, 9T2: 60875.0
# c_5:
# Mean: 9T1: 201120.14084507042, 9T2: 110125.82790224033
# Mediean: 9T1: 88884.0, 9T2: 35194.0
# c_6:
# Mean: 9T1: -1294.443661971831, 9T2: -840.7861507128309
# Mediean: 9T1: -211.0, 9T2: -346.0
# c_7:
# Mean: 9T1: -732.3415492957746, 9T2: -462.0641547861507
# Mediean: 9T1: -657.0, 9T2: -340.0
# c_8:
# Mean: 9T1: -0.4471830985915493, 9T2: -0.8462321792260692
# Mediean: 9T1: 0.0, 9T2: 0.0

# %%
del df_nonic_galois, df_nonic_9T1, df_nonic_9T2
